# %%
####################read dataset#########################
import os
import random
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

image_folder = "data/img"
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith(".jpg")]
#image_files

######################split dataset#######################
random.seed(0)
random.shuffle(image_files)
total_images = len(image_files)
train_ratio = 0.8

train_files = image_files[:int(total_images * train_ratio)]
test_files = image_files[int(total_images * train_ratio):]
#print(train_files)
#print(test_files)

# %%
#Create a vocabulary dictionary that maps all the unique color tokens from your train and test data as keys to a unique integer value.
item_attr_data = pd.read_csv("data/item_attr_data_cleaned.csv")
color_unique = item_attr_data['clothes_color'].unique()
print("number of colors:",len(color_unique))
color_vocab = sorted(set(color_unique))
color_vocabulary = {w:i for i, w in enumerate(color_vocab)}
#print(color_vocabulary)
for i,j in enumerate(item_attr_data['clothes_color']):
    color_value = color_vocabulary[j]
    item_attr_data.loc[i, "clothes_color"] = color_value
# Out:
# number of colors: 759

# %%
###################train dataset label##########################
train_ids=[]
for train_index in train_files:
    parts = train_index.split('/')
    train_ids.append(parts[2][:-4])
    
train_labels = pd.DataFrame(columns=item_attr_data.columns)
train_labels = pd.concat([item_attr_data[item_attr_data['img_idx']==i] for i in train_ids], axis=0, ignore_index=True)
train_labels = train_labels.drop(columns=['index','img_idx'])
train_color = train_labels.pop('clothes_color')

train_color_np = train_color.to_numpy(dtype=np.int32)
train_labels_np = train_labels.to_numpy(dtype=np.float32)
train_labels_np = (train_labels_np + 1) / 2

###################test dataset label##########################
test_ids=[]
for test_index in test_files:
    parts = test_index.split('/')
    test_ids.append(parts[2][:-4])
    
test_labels = pd.DataFrame(columns=item_attr_data.columns)
test_labels = pd.concat([item_attr_data[item_attr_data['img_idx']==i] for i in test_ids], axis=0, ignore_index=True)
test_labels = test_labels.drop(columns=['index','img_idx'])
test_color = test_labels.pop('clothes_color')

test_color_np = test_color.to_numpy(dtype=np.int32)
test_labels_np = test_labels.to_numpy(dtype=np.float32)
test_labels_np = (test_labels_np + 1) / 2

# print(train_labels_np[:5])
# print(train_color_np[:5])

# %%
def load_image(image_file):
    image = tf.io.read_file(image_file)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (64, 64))
    image = tf.cast(image, tf.float32) / 255.0
    return image

# %%
batch_size = 100
train_dataset = tf.data.Dataset.from_tensor_slices(train_files)
train_dataset = train_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices(test_files)
test_dataset = test_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %%
train_color_ids_dataset = tf.data.Dataset.from_tensor_slices(train_color_np)
test_color_ids_dataset = tf.data.Dataset.from_tensor_slices(test_color_np)

train_binary_attributes_dataset = tf.data.Dataset.from_tensor_slices(train_labels_np)
test_binary_attributes_dataset = tf.data.Dataset.from_tensor_slices(test_labels_np)

train_dataset = tf.data.Dataset.zip((train_dataset, train_color_ids_dataset, train_binary_attributes_dataset))
test_dataset = tf.data.Dataset.zip((test_dataset, test_color_ids_dataset, test_binary_attributes_dataset))

train_dataset = train_dataset.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
print(test_dataset)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None), TensorSpec(shape=(None, 463), dtype=tf.float32, name=None))>

# %%
#################show the image####################
# Define a function to display a batch of images
def show_images(image_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.axis('off')
    plt.show()
    
# Get a batch of images from the train_dataset
for images, color_ids, binary_attributes in train_dataset.take(1):
    show_images(images)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input

# Hyperparameters
embedding_dimension = 16
latent_dimension = 256
num_colors = 759
num_binary_attributes = 463
input_shape = (64, 64, 3)

# Cloth color embedding layer
color_embedding = layers.Embedding(num_colors, embedding_dimension, name="color_embedding")

# Encoder
def create_encoder(input_shape, num_attributes):
    inputs = Input(shape=input_shape, name="encoder_input")
    attr_inputs = Input(shape=(num_attributes,), name="attribute_input")
    
    x = layers.Conv2D(32, kernel_size=3, strides=2, padding="same", activation="relu")(inputs)
    x = layers.Conv2D(64, kernel_size=3, strides=2, padding="same", activation="relu")(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(latent_dimension, activation="relu")(x)
    
    attr_x = layers.Dense(latent_dimension, activation="relu")(attr_inputs)
    attr_x = layers.Dense(latent_dimension, activation="relu")(attr_x)
    attr_x = layers.Dense(latent_dimension, activation="relu")(attr_x)
    merged = layers.Concatenate()([x, attr_x])   
    
    z_mean = layers.Dense(latent_dimension, name="z_mean")(merged)
    z_log_var = layers.Dense(latent_dimension, name="z_log_var")(merged)
    
    return Model([inputs, attr_inputs], [z_mean, z_log_var], name="encoder")

def create_unet_decoder(latent_dimension, num_attributes):
    inputs = Input(shape=(latent_dimension + num_attributes,), name="decoder_input")

    x = layers.Dense(64 * 64 * 64, activation="relu")(inputs)
    x = layers.Reshape((64, 64, 64))(x)

    # Encoder part (contracting path)
    e1 = layers.Conv2D(64, kernel_size=3, strides=2, padding="same", activation="relu")(x)
    e2 = layers.Conv2D(128, kernel_size=3, strides=2, padding="same", activation="relu")(e1)

    # Decoder part (expanding path)
    d1 = layers.Conv2DTranspose(128, kernel_size=3, strides=2, padding="same", activation="relu")(e2)
    d1 = layers.Concatenate()([d1, e1])  # Skip connection
    d2 = layers.Conv2DTranspose(64, kernel_size=3, strides=2, padding="same", activation="relu")(d1)
    d2 = layers.Concatenate()([d2, x])  # Skip connection
    print(d2.shape)

    outputs = layers.Conv2DTranspose(3, kernel_size=3, padding="same", activation="sigmoid", name="decoder_output")(d2)

    return Model(inputs, outputs, name="decoder")

# # Decoder
# def create_decoder(latent_dimension, num_attributes):
#     inputs = Input(shape=(latent_dimension + num_attributes,), name="decoder_input")
    
#     x = layers.Dense(latent_dimension, activation="relu")(inputs)
#     x = layers.Dense(16 * 16 * 16, activation="relu")(x)
#     x = layers.Reshape((16, 16, 16))(x)
    
#     x = layers.Conv2DTranspose(64, kernel_size=3, strides=2, padding="same", activation="relu")(x)
#     x = layers.Conv2DTranspose(32, kernel_size=3, strides=2, padding="same", activation="relu")(x)
    
#     outputs = layers.Conv2DTranspose(3, kernel_size=3, padding="same", activation="sigmoid", name="decoder_output")(x)
    
#     return Model(inputs, outputs, name="decoder")

# CVAE Model
class CVAE(Model):
    def __init__(self, encoder, decoder, color_embedding, num_binary_attributes, **kwargs):
        super(CVAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.color_embedding = color_embedding
        self.num_binary_attributes = num_binary_attributes
    
    def call(self, inputs, training=False):
        images, color_ids, binary_attributes = inputs
        
        # Get color embeddings
        color_embeds = self.color_embedding(color_ids)
        
        # Concatenate color embeddings with binary attributes
        attribute_vector = layers.Concatenate(axis=-1)([color_embeds, binary_attributes])
        #attribute_vector = layers.Concatenate(axis=-1)([color_embeds])
        
        # Encode input images and attributes
        z_mean, z_log_var = self.encoder([images, attribute_vector])
        
        # Sample from the latent space
        batch_size = tf.shape(images)[0]
        epsilon = tf.random.normal(shape=(batch_size, latent_dimension))
        z = z_mean + tf.exp(0.5 * z_log_var) * epsilon
        
        # Concatenate latent vector with the attribute vector
        z_cond = layers.Concatenate(axis=-1)([z, attribute_vector])
        
        # Decode the conditioned latent vector
        reconstructed_images = self.decoder(z_cond)
        
        return reconstructed_images, z_mean, z_log_var

# Instantiate the encoder, decoder, and CVAE model
encoder = create_encoder(input_shape, embedding_dimension + num_binary_attributes)
# decoder = create_decoder(latent_dimension, embedding_dimension + num_binary_attributes)
# cvae = CVAE(encoder, decoder, color_embedding, num_binary_attributes)
unet_decoder = create_unet_decoder(latent_dimension, embedding_dimension + num_binary_attributes)
cvae = CVAE(encoder, unet_decoder, color_embedding, num_binary_attributes)
# encoder = create_encoder(input_shape, embedding_dimension)
# decoder = create_decoder(latent_dimension, embedding_dimension)
# cvae = CVAE(encoder, decoder, color_embedding, num_binary_attributes)

# Loss function and optimizer
reconstruction_loss = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# Custom training step
@tf.function
def train_step(images, color_ids, binary_attributes):
    with tf.GradientTape() as tape:
        reconstructed_images, z_mean, z_log_var = cvae([images, color_ids, binary_attributes], training=True)
        
        # Calculate reconstruction loss
        rec_loss = reconstruction_loss(images, reconstructed_images)
        
        # Calculate KL divergence loss
        kl_loss = -0.5 * tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1)
        kl_loss = tf.reduce_mean(kl_loss)
        
        # Combine losses
        total_loss = rec_loss + kl_loss
    
    # Calculate gradients and update model weights
    gradients = tape.gradient(total_loss, cvae.trainable_variables)
    optimizer.apply_gradients(zip(gradients, cvae.trainable_variables))
    
    return total_loss, rec_loss, kl_loss

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")
    
    for batch_images, batch_color_ids, batch_binary_attributes in train_dataset:
        total_loss, rec_loss, kl_loss = train_step(batch_images, batch_color_ids, batch_binary_attributes)
        print(f"Total loss: {total_loss:.4f}, Reconstruction loss: {rec_loss:.4f}, KL loss: {kl_loss:.4f}")
# Out:
# (None, 64, 64, 128)
# Epoch 1/10
# Total loss: 2.7771, Reconstruction loss: 0.1575, KL loss: 2.6196
# Total loss: 1.5010, Reconstruction loss: 0.1614, KL loss: 1.3396
# Total loss: 1.1037, Reconstruction loss: 0.1578, KL loss: 0.9460
# Total loss: 0.9232, Reconstruction loss: 0.1569, KL loss: 0.7663
# Total loss: 0.8152, Reconstruction loss: 0.1588, KL loss: 0.6564
# Total loss: 0.7542, Reconstruction loss: 0.1572, KL loss: 0.5970
# Total loss: 0.6853, Reconstruction loss: 0.1590, KL loss: 0.5263
# Total loss: 0.6704, Reconstruction loss: 0.1565, KL loss: 0.5139
# Total loss: 0.5774, Reconstruction loss: 0.1547, KL loss: 0.4226
# Total loss: 0.5794, Reconstruction loss: 0.1561, KL loss: 0.4233
# Total loss: 0.5650, Reconstruction loss: 0.1571, KL loss: 0.4079
# Total loss: 0.5126, Reconstruction loss: 0.1544, KL loss: 0.3582
# Total loss: 0.4905, Reconstruction loss: 0.1515, KL loss: 0.3390
# Total loss: 0.4622, Reconstruction loss: 0.1493, KL loss: 0.3130
# Total loss: 0.4381, Reconstruction loss: 0.1524, KL loss: 0.2857
# Total loss: 0.4379, Reconstruction loss: 0.1516, KL loss: 0.2862
# Total loss: 0.4088, Reconstruction loss: 0.1524, KL loss: 0.2564
# Total loss: 0.3853, Reconstruction loss: 0.1489, KL loss: 0.2364
# Total loss: 0.3866, Reconstruction loss: 0.1504, KL loss: 0.2362
# Total loss: 0.3692, Reconstruction loss: 0.1492, KL loss: 0.2201
# Total loss: 0.3627, Reconstruction loss: 0.1472, KL loss: 0.2156
# Total loss: 0.3523, Reconstruction loss: 0.1514, KL loss: 0.2009
# Total loss: 0.3394, Reconstruction loss: 0.1462, KL loss: 0.1933
# Total loss: 0.3253, Reconstruction loss: 0.1453, KL loss: 0.1800
# Total loss: 0.3203, Reconstruction loss: 0.1448, KL loss: 0.1756
# Total loss: 0.3035, Reconstruction loss: 0.1402, KL loss: 0.1633
# Total loss: 0.2980, Reconstruction loss: 0.1452, KL loss: 0.1527
# Total loss: 0.2894, Reconstruction loss: 0.1415, KL loss: 0.1479
# Total loss: 0.2867, Reconstruction loss: 0.1400, KL loss: 0.1467
# Total loss: 0.2760, Reconstruction loss: 0.1384, KL loss: 0.1376
# Total loss: 0.2747, Reconstruction loss: 0.1367, KL loss: 0.1380
# Total loss: 0.2639, Reconstruction loss: 0.1348, KL loss: 0.1291
# Total loss: 0.2654, Reconstruction loss: 0.1348, KL loss: 0.1306
# Total loss: 0.2536, Reconstruction loss: 0.1313, KL loss: 0.1223
# Total loss: 0.2498, Reconstruction loss: 0.1282, KL loss: 0.1216
# Total loss: 0.2459, Reconstruction loss: 0.1248, KL loss: 0.1211
# Total loss: 0.2403, Reconstruction loss: 0.1244, KL loss: 0.1159
# Total loss: 0.2344, Reconstruction loss: 0.1191, KL loss: 0.1153
# Total loss: 0.2161, Reconstruction loss: 0.1156, KL loss: 0.1004
# Total loss: 0.2187, Reconstruction loss: 0.1123, KL loss: 0.1064
# Total loss: 0.2063, Reconstruction loss: 0.1067, KL loss: 0.0996
# Total loss: 0.1999, Reconstruction loss: 0.1007, KL loss: 0.0992
# Total loss: 0.1899, Reconstruction loss: 0.0978, KL loss: 0.0921
# Total loss: 0.1850, Reconstruction loss: 0.0912, KL loss: 0.0937
# Total loss: 0.1829, Reconstruction loss: 0.0879, KL loss: 0.0951
# Total loss: 0.1670, Reconstruction loss: 0.0790, KL loss: 0.0880
# Total loss: 0.1677, Reconstruction loss: 0.0787, KL loss: 0.0890
# Total loss: 0.1549, Reconstruction loss: 0.0719, KL loss: 0.0830
# Total loss: 0.1565, Reconstruction loss: 0.0686, KL loss: 0.0879
# Total loss: 0.1456, Reconstruction loss: 0.0630, KL loss: 0.0826
# Total loss: 0.1353, Reconstruction loss: 0.0560, KL loss: 0.0792
# Total loss: 0.1282, Reconstruction loss: 0.0550, KL loss: 0.0731
# Total loss: 0.1263, Reconstruction loss: 0.0524, KL loss: 0.0739
# Total loss: 0.1261, Reconstruction loss: 0.0559, KL loss: 0.0702
# Total loss: 0.1235, Reconstruction loss: 0.0537, KL loss: 0.0697
# Total loss: 0.1267, Reconstruction loss: 0.0532, KL loss: 0.0735
# Total loss: 0.1168, Reconstruction loss: 0.0506, KL loss: 0.0661
# Total loss: 0.1246, Reconstruction loss: 0.0546, KL loss: 0.0700
# Total loss: 0.1114, Reconstruction loss: 0.0491, KL loss: 0.0623
# Total loss: 0.1093, Reconstruction loss: 0.0471, KL loss: 0.0622
# Total loss: 0.1124, Reconstruction loss: 0.0509, KL loss: 0.0615
# Total loss: 0.1089, Reconstruction loss: 0.0529, KL loss: 0.0561
# Total loss: 0.1079, Reconstruction loss: 0.0478, KL loss: 0.0602
# Total loss: 0.1086, Reconstruction loss: 0.0518, KL loss: 0.0568
# Epoch 2/10
# Total loss: 0.1020, Reconstruction loss: 0.0427, KL loss: 0.0593
# Total loss: 0.1025, Reconstruction loss: 0.0447, KL loss: 0.0578
# Total loss: 0.1035, Reconstruction loss: 0.0468, KL loss: 0.0567
# Total loss: 0.0986, Reconstruction loss: 0.0443, KL loss: 0.0544
# Total loss: 0.0980, Reconstruction loss: 0.0449, KL loss: 0.0532
# Total loss: 0.0996, Reconstruction loss: 0.0452, KL loss: 0.0544
# Total loss: 0.0933, Reconstruction loss: 0.0415, KL loss: 0.0517
# Total loss: 0.0921, Reconstruction loss: 0.0387, KL loss: 0.0534
# Total loss: 0.0878, Reconstruction loss: 0.0411, KL loss: 0.0467
# Total loss: 0.0923, Reconstruction loss: 0.0425, KL loss: 0.0498
# Total loss: 0.0869, Reconstruction loss: 0.0384, KL loss: 0.0485
# Total loss: 0.0860, Reconstruction loss: 0.0420, KL loss: 0.0440
# Total loss: 0.0891, Reconstruction loss: 0.0423, KL loss: 0.0469
# Total loss: 0.0854, Reconstruction loss: 0.0415, KL loss: 0.0439
# Total loss: 0.0833, Reconstruction loss: 0.0409, KL loss: 0.0424
# Total loss: 0.0861, Reconstruction loss: 0.0405, KL loss: 0.0456
# Total loss: 0.0811, Reconstruction loss: 0.0399, KL loss: 0.0412
# Total loss: 0.0792, Reconstruction loss: 0.0400, KL loss: 0.0392
# Total loss: 0.0814, Reconstruction loss: 0.0405, KL loss: 0.0409
# Total loss: 0.0803, Reconstruction loss: 0.0399, KL loss: 0.0404
# Total loss: 0.0790, Reconstruction loss: 0.0408, KL loss: 0.0383
# Total loss: 0.0798, Reconstruction loss: 0.0414, KL loss: 0.0384
# Total loss: 0.0814, Reconstruction loss: 0.0435, KL loss: 0.0379
# Total loss: 0.0747, Reconstruction loss: 0.0390, KL loss: 0.0357
# Total loss: 0.0760, Reconstruction loss: 0.0387, KL loss: 0.0373
# Total loss: 0.0744, Reconstruction loss: 0.0397, KL loss: 0.0347
# Total loss: 0.0743, Reconstruction loss: 0.0415, KL loss: 0.0327
# Total loss: 0.0744, Reconstruction loss: 0.0408, KL loss: 0.0336
# Total loss: 0.0702, Reconstruction loss: 0.0371, KL loss: 0.0330
# Total loss: 0.0758, Reconstruction loss: 0.0431, KL loss: 0.0327
# Total loss: 0.0712, Reconstruction loss: 0.0386, KL loss: 0.0326
# Total loss: 0.0703, Reconstruction loss: 0.0388, KL loss: 0.0315
# Total loss: 0.0720, Reconstruction loss: 0.0396, KL loss: 0.0324
# Total loss: 0.0731, Reconstruction loss: 0.0424, KL loss: 0.0307
# Total loss: 0.0684, Reconstruction loss: 0.0370, KL loss: 0.0315
# Total loss: 0.0726, Reconstruction loss: 0.0399, KL loss: 0.0327
# Total loss: 0.0690, Reconstruction loss: 0.0381, KL loss: 0.0309
# Total loss: 0.0696, Reconstruction loss: 0.0394, KL loss: 0.0302
# Total loss: 0.0649, Reconstruction loss: 0.0381, KL loss: 0.0268
# Total loss: 0.0707, Reconstruction loss: 0.0413, KL loss: 0.0294
# Total loss: 0.0647, Reconstruction loss: 0.0367, KL loss: 0.0281
# Total loss: 0.0659, Reconstruction loss: 0.0388, KL loss: 0.0271
# Total loss: 0.0644, Reconstruction loss: 0.0389, KL loss: 0.0255
# Total loss: 0.0648, Reconstruction loss: 0.0384, KL loss: 0.0264
# Total loss: 0.0689, Reconstruction loss: 0.0411, KL loss: 0.0278
# Total loss: 0.0622, Reconstruction loss: 0.0370, KL loss: 0.0252
# Total loss: 0.0683, Reconstruction loss: 0.0420, KL loss: 0.0264
# Total loss: 0.0655, Reconstruction loss: 0.0407, KL loss: 0.0248
# Total loss: 0.0673, Reconstruction loss: 0.0404, KL loss: 0.0269
# Total loss: 0.0651, Reconstruction loss: 0.0400, KL loss: 0.0251
# Total loss: 0.0615, Reconstruction loss: 0.0377, KL loss: 0.0238
# Total loss: 0.0602, Reconstruction loss: 0.0383, KL loss: 0.0219
# Total loss: 0.0602, Reconstruction loss: 0.0382, KL loss: 0.0221
# Total loss: 0.0607, Reconstruction loss: 0.0397, KL loss: 0.0210
# Total loss: 0.0609, Reconstruction loss: 0.0401, KL loss: 0.0208
# Total loss: 0.0612, Reconstruction loss: 0.0384, KL loss: 0.0229
# Total loss: 0.0593, Reconstruction loss: 0.0388, KL loss: 0.0205
# Total loss: 0.0621, Reconstruction loss: 0.0402, KL loss: 0.0219
# Total loss: 0.0575, Reconstruction loss: 0.0379, KL loss: 0.0196
# Total loss: 0.0564, Reconstruction loss: 0.0369, KL loss: 0.0195
# Total loss: 0.0569, Reconstruction loss: 0.0386, KL loss: 0.0183
# Total loss: 0.0586, Reconstruction loss: 0.0411, KL loss: 0.0175
# Total loss: 0.0578, Reconstruction loss: 0.0384, KL loss: 0.0194
# Total loss: 0.0579, Reconstruction loss: 0.0410, KL loss: 0.0170
# Epoch 3/10
# Total loss: 0.0560, Reconstruction loss: 0.0362, KL loss: 0.0197
# Total loss: 0.0568, Reconstruction loss: 0.0377, KL loss: 0.0190
# Total loss: 0.0579, Reconstruction loss: 0.0395, KL loss: 0.0184
# Total loss: 0.0558, Reconstruction loss: 0.0385, KL loss: 0.0173
# Total loss: 0.0564, Reconstruction loss: 0.0397, KL loss: 0.0167
# Total loss: 0.0586, Reconstruction loss: 0.0408, KL loss: 0.0178
# Total loss: 0.0548, Reconstruction loss: 0.0381, KL loss: 0.0168
# Total loss: 0.0523, Reconstruction loss: 0.0357, KL loss: 0.0165
# Total loss: 0.0537, Reconstruction loss: 0.0380, KL loss: 0.0157
# Total loss: 0.0564, Reconstruction loss: 0.0397, KL loss: 0.0167
# Total loss: 0.0515, Reconstruction loss: 0.0361, KL loss: 0.0154
# Total loss: 0.0538, Reconstruction loss: 0.0393, KL loss: 0.0145
# Total loss: 0.0551, Reconstruction loss: 0.0395, KL loss: 0.0156
# Total loss: 0.0526, Reconstruction loss: 0.0384, KL loss: 0.0142
# Total loss: 0.0527, Reconstruction loss: 0.0386, KL loss: 0.0141
# Total loss: 0.0530, Reconstruction loss: 0.0379, KL loss: 0.0151
# Total loss: 0.0510, Reconstruction loss: 0.0375, KL loss: 0.0135
# Total loss: 0.0502, Reconstruction loss: 0.0372, KL loss: 0.0130
# Total loss: 0.0516, Reconstruction loss: 0.0384, KL loss: 0.0133
# Total loss: 0.0518, Reconstruction loss: 0.0381, KL loss: 0.0137
# Total loss: 0.0511, Reconstruction loss: 0.0392, KL loss: 0.0119
# Total loss: 0.0512, Reconstruction loss: 0.0387, KL loss: 0.0125
# Total loss: 0.0541, Reconstruction loss: 0.0418, KL loss: 0.0123
# Total loss: 0.0481, Reconstruction loss: 0.0369, KL loss: 0.0112
# Total loss: 0.0495, Reconstruction loss: 0.0369, KL loss: 0.0125
# Total loss: 0.0488, Reconstruction loss: 0.0378, KL loss: 0.0109
# Total loss: 0.0499, Reconstruction loss: 0.0392, KL loss: 0.0107
# Total loss: 0.0498, Reconstruction loss: 0.0388, KL loss: 0.0110
# Total loss: 0.0461, Reconstruction loss: 0.0355, KL loss: 0.0106
# Total loss: 0.0517, Reconstruction loss: 0.0412, KL loss: 0.0104
# Total loss: 0.0476, Reconstruction loss: 0.0373, KL loss: 0.0104
# Total loss: 0.0485, Reconstruction loss: 0.0378, KL loss: 0.0107
# Total loss: 0.0483, Reconstruction loss: 0.0381, KL loss: 0.0102
# Total loss: 0.0508, Reconstruction loss: 0.0409, KL loss: 0.0098
# Total loss: 0.0462, Reconstruction loss: 0.0361, KL loss: 0.0101
# Total loss: 0.0491, Reconstruction loss: 0.0382, KL loss: 0.0109
# Total loss: 0.0466, Reconstruction loss: 0.0367, KL loss: 0.0099
# Total loss: 0.0472, Reconstruction loss: 0.0378, KL loss: 0.0094
# Total loss: 0.0451, Reconstruction loss: 0.0364, KL loss: 0.0087
# Total loss: 0.0495, Reconstruction loss: 0.0398, KL loss: 0.0098
# Total loss: 0.0445, Reconstruction loss: 0.0356, KL loss: 0.0090
# Total loss: 0.0453, Reconstruction loss: 0.0369, KL loss: 0.0084
# Total loss: 0.0460, Reconstruction loss: 0.0381, KL loss: 0.0079
# Total loss: 0.0455, Reconstruction loss: 0.0372, KL loss: 0.0083
# Total loss: 0.0492, Reconstruction loss: 0.0404, KL loss: 0.0089
# Total loss: 0.0435, Reconstruction loss: 0.0356, KL loss: 0.0079
# Total loss: 0.0495, Reconstruction loss: 0.0408, KL loss: 0.0087
# Total loss: 0.0473, Reconstruction loss: 0.0393, KL loss: 0.0080
# Total loss: 0.0477, Reconstruction loss: 0.0393, KL loss: 0.0084
# Total loss: 0.0471, Reconstruction loss: 0.0391, KL loss: 0.0081
# Total loss: 0.0439, Reconstruction loss: 0.0366, KL loss: 0.0073
# Total loss: 0.0448, Reconstruction loss: 0.0380, KL loss: 0.0068
# Total loss: 0.0437, Reconstruction loss: 0.0370, KL loss: 0.0067
# Total loss: 0.0451, Reconstruction loss: 0.0386, KL loss: 0.0065
# Total loss: 0.0452, Reconstruction loss: 0.0388, KL loss: 0.0064
# Total loss: 0.0446, Reconstruction loss: 0.0373, KL loss: 0.0072
# Total loss: 0.0442, Reconstruction loss: 0.0377, KL loss: 0.0065
# Total loss: 0.0456, Reconstruction loss: 0.0390, KL loss: 0.0066
# Total loss: 0.0430, Reconstruction loss: 0.0367, KL loss: 0.0062
# Total loss: 0.0416, Reconstruction loss: 0.0358, KL loss: 0.0058
# Total loss: 0.0432, Reconstruction loss: 0.0379, KL loss: 0.0053
# Total loss: 0.0461, Reconstruction loss: 0.0405, KL loss: 0.0056
# Total loss: 0.0434, Reconstruction loss: 0.0374, KL loss: 0.0060
# Total loss: 0.0452, Reconstruction loss: 0.0399, KL loss: 0.0053
# Epoch 4/10
# Total loss: 0.0417, Reconstruction loss: 0.0352, KL loss: 0.0065
# Total loss: 0.0429, Reconstruction loss: 0.0369, KL loss: 0.0060
# Total loss: 0.0443, Reconstruction loss: 0.0385, KL loss: 0.0058
# Total loss: 0.0427, Reconstruction loss: 0.0373, KL loss: 0.0054
# Total loss: 0.0436, Reconstruction loss: 0.0387, KL loss: 0.0049
# Total loss: 0.0452, Reconstruction loss: 0.0396, KL loss: 0.0057
# Total loss: 0.0425, Reconstruction loss: 0.0372, KL loss: 0.0053
# Total loss: 0.0399, Reconstruction loss: 0.0349, KL loss: 0.0050
# Total loss: 0.0422, Reconstruction loss: 0.0372, KL loss: 0.0050
# Total loss: 0.0447, Reconstruction loss: 0.0391, KL loss: 0.0056
# Total loss: 0.0403, Reconstruction loss: 0.0356, KL loss: 0.0047
# Total loss: 0.0435, Reconstruction loss: 0.0388, KL loss: 0.0048
# Total loss: 0.0440, Reconstruction loss: 0.0389, KL loss: 0.0052
# Total loss: 0.0428, Reconstruction loss: 0.0383, KL loss: 0.0045
# Total loss: 0.0424, Reconstruction loss: 0.0378, KL loss: 0.0046
# Total loss: 0.0421, Reconstruction loss: 0.0372, KL loss: 0.0050
# Total loss: 0.0413, Reconstruction loss: 0.0370, KL loss: 0.0043
# Total loss: 0.0409, Reconstruction loss: 0.0367, KL loss: 0.0043
# Total loss: 0.0422, Reconstruction loss: 0.0379, KL loss: 0.0043
# Total loss: 0.0418, Reconstruction loss: 0.0372, KL loss: 0.0046
# Total loss: 0.0421, Reconstruction loss: 0.0383, KL loss: 0.0038
# Total loss: 0.0422, Reconstruction loss: 0.0382, KL loss: 0.0040
# Total loss: 0.0448, Reconstruction loss: 0.0408, KL loss: 0.0040
# Total loss: 0.0396, Reconstruction loss: 0.0362, KL loss: 0.0034
# Total loss: 0.0409, Reconstruction loss: 0.0367, KL loss: 0.0042
# Total loss: 0.0409, Reconstruction loss: 0.0375, KL loss: 0.0034
# Total loss: 0.0422, Reconstruction loss: 0.0387, KL loss: 0.0036
# Total loss: 0.0418, Reconstruction loss: 0.0383, KL loss: 0.0035
# Total loss: 0.0382, Reconstruction loss: 0.0349, KL loss: 0.0032
# Total loss: 0.0439, Reconstruction loss: 0.0406, KL loss: 0.0033
# Total loss: 0.0400, Reconstruction loss: 0.0366, KL loss: 0.0034
# Total loss: 0.0403, Reconstruction loss: 0.0367, KL loss: 0.0036
# Total loss: 0.0410, Reconstruction loss: 0.0378, KL loss: 0.0033
# Total loss: 0.0438, Reconstruction loss: 0.0406, KL loss: 0.0032
# Total loss: 0.0386, Reconstruction loss: 0.0353, KL loss: 0.0033
# Total loss: 0.0411, Reconstruction loss: 0.0374, KL loss: 0.0037
# Total loss: 0.0393, Reconstruction loss: 0.0361, KL loss: 0.0032
# Total loss: 0.0403, Reconstruction loss: 0.0373, KL loss: 0.0031
# Total loss: 0.0392, Reconstruction loss: 0.0364, KL loss: 0.0029
# Total loss: 0.0423, Reconstruction loss: 0.0389, KL loss: 0.0033
# Total loss: 0.0378, Reconstruction loss: 0.0348, KL loss: 0.0031
# Total loss: 0.0394, Reconstruction loss: 0.0366, KL loss: 0.0028
# Total loss: 0.0398, Reconstruction loss: 0.0371, KL loss: 0.0026
# Total loss: 0.0389, Reconstruction loss: 0.0362, KL loss: 0.0027
# Total loss: 0.0422, Reconstruction loss: 0.0393, KL loss: 0.0029
# Total loss: 0.0377, Reconstruction loss: 0.0352, KL loss: 0.0025
# Total loss: 0.0433, Reconstruction loss: 0.0403, KL loss: 0.0031
# Total loss: 0.0413, Reconstruction loss: 0.0384, KL loss: 0.0029
# Total loss: 0.0413, Reconstruction loss: 0.0385, KL loss: 0.0028
# Total loss: 0.0410, Reconstruction loss: 0.0381, KL loss: 0.0029
# Total loss: 0.0386, Reconstruction loss: 0.0361, KL loss: 0.0025
# Total loss: 0.0393, Reconstruction loss: 0.0368, KL loss: 0.0024
# Total loss: 0.0384, Reconstruction loss: 0.0361, KL loss: 0.0023
# Total loss: 0.0399, Reconstruction loss: 0.0378, KL loss: 0.0021
# Total loss: 0.0403, Reconstruction loss: 0.0381, KL loss: 0.0022
# Total loss: 0.0391, Reconstruction loss: 0.0366, KL loss: 0.0025
# Total loss: 0.0396, Reconstruction loss: 0.0372, KL loss: 0.0025
# Total loss: 0.0405, Reconstruction loss: 0.0382, KL loss: 0.0022
# Total loss: 0.0382, Reconstruction loss: 0.0360, KL loss: 0.0022
# Total loss: 0.0371, Reconstruction loss: 0.0352, KL loss: 0.0020
# Total loss: 0.0389, Reconstruction loss: 0.0371, KL loss: 0.0018
# Total loss: 0.0415, Reconstruction loss: 0.0394, KL loss: 0.0021
# Total loss: 0.0390, Reconstruction loss: 0.0369, KL loss: 0.0021
# Total loss: 0.0410, Reconstruction loss: 0.0391, KL loss: 0.0019
# Epoch 5/10
# Total loss: 0.0373, Reconstruction loss: 0.0350, KL loss: 0.0023
# Total loss: 0.0387, Reconstruction loss: 0.0366, KL loss: 0.0021
# Total loss: 0.0400, Reconstruction loss: 0.0378, KL loss: 0.0021
# Total loss: 0.0392, Reconstruction loss: 0.0373, KL loss: 0.0019
# Total loss: 0.0396, Reconstruction loss: 0.0380, KL loss: 0.0016
# Total loss: 0.0412, Reconstruction loss: 0.0392, KL loss: 0.0020
# Total loss: 0.0385, Reconstruction loss: 0.0366, KL loss: 0.0019
# Total loss: 0.0361, Reconstruction loss: 0.0342, KL loss: 0.0018
# Total loss: 0.0384, Reconstruction loss: 0.0365, KL loss: 0.0019
# Total loss: 0.0405, Reconstruction loss: 0.0383, KL loss: 0.0022
# Total loss: 0.0368, Reconstruction loss: 0.0351, KL loss: 0.0017
# Total loss: 0.0397, Reconstruction loss: 0.0379, KL loss: 0.0018
# Total loss: 0.0401, Reconstruction loss: 0.0381, KL loss: 0.0020
# Total loss: 0.0391, Reconstruction loss: 0.0375, KL loss: 0.0017
# Total loss: 0.0389, Reconstruction loss: 0.0371, KL loss: 0.0017
# Total loss: 0.0388, Reconstruction loss: 0.0369, KL loss: 0.0019
# Total loss: 0.0380, Reconstruction loss: 0.0363, KL loss: 0.0017
# Total loss: 0.0381, Reconstruction loss: 0.0365, KL loss: 0.0016
# Total loss: 0.0388, Reconstruction loss: 0.0371, KL loss: 0.0017
# Total loss: 0.0387, Reconstruction loss: 0.0369, KL loss: 0.0018
# Total loss: 0.0395, Reconstruction loss: 0.0381, KL loss: 0.0014
# Total loss: 0.0395, Reconstruction loss: 0.0379, KL loss: 0.0016
# Total loss: 0.0419, Reconstruction loss: 0.0403, KL loss: 0.0016
# Total loss: 0.0376, Reconstruction loss: 0.0364, KL loss: 0.0013
# Total loss: 0.0377, Reconstruction loss: 0.0361, KL loss: 0.0016
# Total loss: 0.0374, Reconstruction loss: 0.0361, KL loss: 0.0013
# Total loss: 0.0399, Reconstruction loss: 0.0384, KL loss: 0.0014
# Total loss: 0.0389, Reconstruction loss: 0.0376, KL loss: 0.0014
# Total loss: 0.0356, Reconstruction loss: 0.0344, KL loss: 0.0012
# Total loss: 0.0412, Reconstruction loss: 0.0399, KL loss: 0.0013
# Total loss: 0.0377, Reconstruction loss: 0.0363, KL loss: 0.0013
# Total loss: 0.0379, Reconstruction loss: 0.0365, KL loss: 0.0014
# Total loss: 0.0382, Reconstruction loss: 0.0370, KL loss: 0.0013
# Total loss: 0.0414, Reconstruction loss: 0.0401, KL loss: 0.0013
# Total loss: 0.0360, Reconstruction loss: 0.0347, KL loss: 0.0013
# Total loss: 0.0386, Reconstruction loss: 0.0371, KL loss: 0.0015
# Total loss: 0.0367, Reconstruction loss: 0.0355, KL loss: 0.0012
# Total loss: 0.0379, Reconstruction loss: 0.0366, KL loss: 0.0012
# Total loss: 0.0363, Reconstruction loss: 0.0352, KL loss: 0.0011
# Total loss: 0.0402, Reconstruction loss: 0.0388, KL loss: 0.0014
# Total loss: 0.0358, Reconstruction loss: 0.0346, KL loss: 0.0013
# Total loss: 0.0373, Reconstruction loss: 0.0361, KL loss: 0.0012
# Total loss: 0.0376, Reconstruction loss: 0.0366, KL loss: 0.0011
# Total loss: 0.0373, Reconstruction loss: 0.0362, KL loss: 0.0011
# Total loss: 0.0397, Reconstruction loss: 0.0386, KL loss: 0.0011
# Total loss: 0.0356, Reconstruction loss: 0.0346, KL loss: 0.0009
# Total loss: 0.0412, Reconstruction loss: 0.0399, KL loss: 0.0013
# Total loss: 0.0392, Reconstruction loss: 0.0378, KL loss: 0.0013
# Total loss: 0.0393, Reconstruction loss: 0.0382, KL loss: 0.0012
# Total loss: 0.0391, Reconstruction loss: 0.0379, KL loss: 0.0012
# Total loss: 0.0364, Reconstruction loss: 0.0353, KL loss: 0.0011
# Total loss: 0.0379, Reconstruction loss: 0.0368, KL loss: 0.0011
# Total loss: 0.0365, Reconstruction loss: 0.0355, KL loss: 0.0009
# Total loss: 0.0378, Reconstruction loss: 0.0370, KL loss: 0.0008
# Total loss: 0.0389, Reconstruction loss: 0.0381, KL loss: 0.0009
# Total loss: 0.0373, Reconstruction loss: 0.0362, KL loss: 0.0011
# Total loss: 0.0379, Reconstruction loss: 0.0368, KL loss: 0.0011
# Total loss: 0.0387, Reconstruction loss: 0.0378, KL loss: 0.0010
# Total loss: 0.0365, Reconstruction loss: 0.0355, KL loss: 0.0009
# Total loss: 0.0353, Reconstruction loss: 0.0345, KL loss: 0.0008
# Total loss: 0.0371, Reconstruction loss: 0.0364, KL loss: 0.0008
# Total loss: 0.0398, Reconstruction loss: 0.0388, KL loss: 0.0010
# Total loss: 0.0371, Reconstruction loss: 0.0362, KL loss: 0.0009
# Total loss: 0.0396, Reconstruction loss: 0.0388, KL loss: 0.0008
# Epoch 6/10
# Total loss: 0.0349, Reconstruction loss: 0.0338, KL loss: 0.0010
# Total loss: 0.0368, Reconstruction loss: 0.0359, KL loss: 0.0009
# Total loss: 0.0383, Reconstruction loss: 0.0373, KL loss: 0.0010
# Total loss: 0.0375, Reconstruction loss: 0.0367, KL loss: 0.0008
# Total loss: 0.0382, Reconstruction loss: 0.0376, KL loss: 0.0006
# Total loss: 0.0401, Reconstruction loss: 0.0392, KL loss: 0.0009
# Total loss: 0.0365, Reconstruction loss: 0.0357, KL loss: 0.0008
# Total loss: 0.0348, Reconstruction loss: 0.0340, KL loss: 0.0008
# Total loss: 0.0364, Reconstruction loss: 0.0356, KL loss: 0.0008
# Total loss: 0.0386, Reconstruction loss: 0.0376, KL loss: 0.0010
# Total loss: 0.0357, Reconstruction loss: 0.0350, KL loss: 0.0007
# Total loss: 0.0381, Reconstruction loss: 0.0373, KL loss: 0.0008
# Total loss: 0.0387, Reconstruction loss: 0.0378, KL loss: 0.0009
# Total loss: 0.0379, Reconstruction loss: 0.0372, KL loss: 0.0008
# Total loss: 0.0372, Reconstruction loss: 0.0365, KL loss: 0.0007
# Total loss: 0.0371, Reconstruction loss: 0.0362, KL loss: 0.0009
# Total loss: 0.0366, Reconstruction loss: 0.0358, KL loss: 0.0008
# Total loss: 0.0367, Reconstruction loss: 0.0359, KL loss: 0.0008
# Total loss: 0.0374, Reconstruction loss: 0.0366, KL loss: 0.0008
# Total loss: 0.0372, Reconstruction loss: 0.0363, KL loss: 0.0009
# Total loss: 0.0389, Reconstruction loss: 0.0382, KL loss: 0.0007
# Total loss: 0.0380, Reconstruction loss: 0.0374, KL loss: 0.0007
# Total loss: 0.0402, Reconstruction loss: 0.0395, KL loss: 0.0008
# Total loss: 0.0364, Reconstruction loss: 0.0358, KL loss: 0.0006
# Total loss: 0.0359, Reconstruction loss: 0.0352, KL loss: 0.0007
# Total loss: 0.0364, Reconstruction loss: 0.0358, KL loss: 0.0006
# Total loss: 0.0381, Reconstruction loss: 0.0374, KL loss: 0.0007
# Total loss: 0.0375, Reconstruction loss: 0.0369, KL loss: 0.0006
# Total loss: 0.0345, Reconstruction loss: 0.0340, KL loss: 0.0005
# Total loss: 0.0400, Reconstruction loss: 0.0394, KL loss: 0.0006
# Total loss: 0.0367, Reconstruction loss: 0.0361, KL loss: 0.0006
# Total loss: 0.0364, Reconstruction loss: 0.0357, KL loss: 0.0007
# Total loss: 0.0369, Reconstruction loss: 0.0363, KL loss: 0.0006
# Total loss: 0.0404, Reconstruction loss: 0.0398, KL loss: 0.0006
# Total loss: 0.0348, Reconstruction loss: 0.0342, KL loss: 0.0006
# Total loss: 0.0375, Reconstruction loss: 0.0368, KL loss: 0.0007
# Total loss: 0.0356, Reconstruction loss: 0.0351, KL loss: 0.0005
# Total loss: 0.0370, Reconstruction loss: 0.0364, KL loss: 0.0006
# Total loss: 0.0358, Reconstruction loss: 0.0353, KL loss: 0.0005
# Total loss: 0.0386, Reconstruction loss: 0.0380, KL loss: 0.0007
# Total loss: 0.0346, Reconstruction loss: 0.0340, KL loss: 0.0006
# Total loss: 0.0361, Reconstruction loss: 0.0355, KL loss: 0.0006
# Total loss: 0.0369, Reconstruction loss: 0.0364, KL loss: 0.0005
# Total loss: 0.0364, Reconstruction loss: 0.0359, KL loss: 0.0005
# Total loss: 0.0388, Reconstruction loss: 0.0383, KL loss: 0.0005
# Total loss: 0.0344, Reconstruction loss: 0.0340, KL loss: 0.0004
# Total loss: 0.0399, Reconstruction loss: 0.0393, KL loss: 0.0006
# Total loss: 0.0380, Reconstruction loss: 0.0373, KL loss: 0.0007
# Total loss: 0.0384, Reconstruction loss: 0.0379, KL loss: 0.0006
# Total loss: 0.0378, Reconstruction loss: 0.0372, KL loss: 0.0006
# Total loss: 0.0358, Reconstruction loss: 0.0353, KL loss: 0.0005
# Total loss: 0.0369, Reconstruction loss: 0.0363, KL loss: 0.0006
# Total loss: 0.0357, Reconstruction loss: 0.0353, KL loss: 0.0004
# Total loss: 0.0369, Reconstruction loss: 0.0365, KL loss: 0.0004
# Total loss: 0.0376, Reconstruction loss: 0.0371, KL loss: 0.0004
# Total loss: 0.0362, Reconstruction loss: 0.0357, KL loss: 0.0005
# Total loss: 0.0370, Reconstruction loss: 0.0364, KL loss: 0.0005
# Total loss: 0.0377, Reconstruction loss: 0.0372, KL loss: 0.0005
# Total loss: 0.0358, Reconstruction loss: 0.0353, KL loss: 0.0004
# Total loss: 0.0346, Reconstruction loss: 0.0342, KL loss: 0.0004
# Total loss: 0.0366, Reconstruction loss: 0.0362, KL loss: 0.0004
# Total loss: 0.0395, Reconstruction loss: 0.0390, KL loss: 0.0005
# Total loss: 0.0362, Reconstruction loss: 0.0357, KL loss: 0.0005
# Total loss: 0.0386, Reconstruction loss: 0.0382, KL loss: 0.0004
# Epoch 7/10
# Total loss: 0.0345, Reconstruction loss: 0.0340, KL loss: 0.0005
# Total loss: 0.0362, Reconstruction loss: 0.0357, KL loss: 0.0004
# Total loss: 0.0378, Reconstruction loss: 0.0373, KL loss: 0.0005
# Total loss: 0.0366, Reconstruction loss: 0.0362, KL loss: 0.0004
# Total loss: 0.0374, Reconstruction loss: 0.0371, KL loss: 0.0003
# Total loss: 0.0391, Reconstruction loss: 0.0387, KL loss: 0.0004
# Total loss: 0.0361, Reconstruction loss: 0.0357, KL loss: 0.0004
# Total loss: 0.0346, Reconstruction loss: 0.0342, KL loss: 0.0004
# Total loss: 0.0357, Reconstruction loss: 0.0353, KL loss: 0.0004
# Total loss: 0.0379, Reconstruction loss: 0.0374, KL loss: 0.0005
# Total loss: 0.0348, Reconstruction loss: 0.0344, KL loss: 0.0004
# Total loss: 0.0372, Reconstruction loss: 0.0368, KL loss: 0.0004
# Total loss: 0.0377, Reconstruction loss: 0.0373, KL loss: 0.0005
# Total loss: 0.0368, Reconstruction loss: 0.0364, KL loss: 0.0004
# Total loss: 0.0368, Reconstruction loss: 0.0364, KL loss: 0.0004
# Total loss: 0.0360, Reconstruction loss: 0.0355, KL loss: 0.0005
# Total loss: 0.0361, Reconstruction loss: 0.0357, KL loss: 0.0004
# Total loss: 0.0357, Reconstruction loss: 0.0353, KL loss: 0.0004
# Total loss: 0.0363, Reconstruction loss: 0.0358, KL loss: 0.0004
# Total loss: 0.0364, Reconstruction loss: 0.0359, KL loss: 0.0005
# Total loss: 0.0382, Reconstruction loss: 0.0378, KL loss: 0.0004
# Total loss: 0.0373, Reconstruction loss: 0.0370, KL loss: 0.0003
# Total loss: 0.0397, Reconstruction loss: 0.0392, KL loss: 0.0004
# Total loss: 0.0359, Reconstruction loss: 0.0357, KL loss: 0.0003
# Total loss: 0.0356, Reconstruction loss: 0.0352, KL loss: 0.0004
# Total loss: 0.0356, Reconstruction loss: 0.0353, KL loss: 0.0003
# Total loss: 0.0380, Reconstruction loss: 0.0376, KL loss: 0.0004
# Total loss: 0.0369, Reconstruction loss: 0.0365, KL loss: 0.0003
# Total loss: 0.0341, Reconstruction loss: 0.0338, KL loss: 0.0003
# Total loss: 0.0398, Reconstruction loss: 0.0395, KL loss: 0.0003
# Total loss: 0.0361, Reconstruction loss: 0.0358, KL loss: 0.0003
# Total loss: 0.0359, Reconstruction loss: 0.0355, KL loss: 0.0003
# Total loss: 0.0363, Reconstruction loss: 0.0361, KL loss: 0.0003
# Total loss: 0.0400, Reconstruction loss: 0.0397, KL loss: 0.0003
# Total loss: 0.0342, Reconstruction loss: 0.0339, KL loss: 0.0003
# Total loss: 0.0361, Reconstruction loss: 0.0357, KL loss: 0.0004
# Total loss: 0.0348, Reconstruction loss: 0.0345, KL loss: 0.0002
# Total loss: 0.0362, Reconstruction loss: 0.0359, KL loss: 0.0003
# Total loss: 0.0356, Reconstruction loss: 0.0354, KL loss: 0.0002
# Total loss: 0.0381, Reconstruction loss: 0.0377, KL loss: 0.0003
# Total loss: 0.0339, Reconstruction loss: 0.0335, KL loss: 0.0003
# Total loss: 0.0354, Reconstruction loss: 0.0351, KL loss: 0.0003
# Total loss: 0.0363, Reconstruction loss: 0.0360, KL loss: 0.0003
# Total loss: 0.0357, Reconstruction loss: 0.0355, KL loss: 0.0002
# Total loss: 0.0378, Reconstruction loss: 0.0376, KL loss: 0.0002
# Total loss: 0.0338, Reconstruction loss: 0.0336, KL loss: 0.0002
# Total loss: 0.0395, Reconstruction loss: 0.0392, KL loss: 0.0003
# Total loss: 0.0370, Reconstruction loss: 0.0366, KL loss: 0.0004
# Total loss: 0.0379, Reconstruction loss: 0.0376, KL loss: 0.0003
# Total loss: 0.0371, Reconstruction loss: 0.0368, KL loss: 0.0003
# Total loss: 0.0350, Reconstruction loss: 0.0347, KL loss: 0.0003
# Total loss: 0.0364, Reconstruction loss: 0.0361, KL loss: 0.0003
# Total loss: 0.0348, Reconstruction loss: 0.0346, KL loss: 0.0002
# Total loss: 0.0367, Reconstruction loss: 0.0365, KL loss: 0.0002
# Total loss: 0.0369, Reconstruction loss: 0.0367, KL loss: 0.0002
# Total loss: 0.0354, Reconstruction loss: 0.0351, KL loss: 0.0003
# Total loss: 0.0365, Reconstruction loss: 0.0362, KL loss: 0.0003
# Total loss: 0.0366, Reconstruction loss: 0.0364, KL loss: 0.0003
# Total loss: 0.0354, Reconstruction loss: 0.0352, KL loss: 0.0002
# Total loss: 0.0341, Reconstruction loss: 0.0339, KL loss: 0.0002
# Total loss: 0.0368, Reconstruction loss: 0.0366, KL loss: 0.0002
# Total loss: 0.0389, Reconstruction loss: 0.0386, KL loss: 0.0003
# Total loss: 0.0354, Reconstruction loss: 0.0352, KL loss: 0.0003
# Total loss: 0.0379, Reconstruction loss: 0.0377, KL loss: 0.0002
# Epoch 8/10
# Total loss: 0.0339, Reconstruction loss: 0.0336, KL loss: 0.0003
# Total loss: 0.0358, Reconstruction loss: 0.0356, KL loss: 0.0002
# Total loss: 0.0366, Reconstruction loss: 0.0363, KL loss: 0.0003
# Total loss: 0.0365, Reconstruction loss: 0.0363, KL loss: 0.0002
# Total loss: 0.0368, Reconstruction loss: 0.0367, KL loss: 0.0001
# Total loss: 0.0386, Reconstruction loss: 0.0384, KL loss: 0.0002
# Total loss: 0.0353, Reconstruction loss: 0.0351, KL loss: 0.0002
# Total loss: 0.0339, Reconstruction loss: 0.0337, KL loss: 0.0002
# Total loss: 0.0354, Reconstruction loss: 0.0352, KL loss: 0.0002
# Total loss: 0.0377, Reconstruction loss: 0.0374, KL loss: 0.0003
# Total loss: 0.0342, Reconstruction loss: 0.0340, KL loss: 0.0002
# Total loss: 0.0367, Reconstruction loss: 0.0365, KL loss: 0.0002
# Total loss: 0.0375, Reconstruction loss: 0.0373, KL loss: 0.0003
# Total loss: 0.0362, Reconstruction loss: 0.0360, KL loss: 0.0002
# Total loss: 0.0362, Reconstruction loss: 0.0361, KL loss: 0.0002
# Total loss: 0.0359, Reconstruction loss: 0.0356, KL loss: 0.0003
# Total loss: 0.0356, Reconstruction loss: 0.0354, KL loss: 0.0002
# Total loss: 0.0353, Reconstruction loss: 0.0351, KL loss: 0.0002
# Total loss: 0.0358, Reconstruction loss: 0.0355, KL loss: 0.0002
# Total loss: 0.0359, Reconstruction loss: 0.0356, KL loss: 0.0003
# Total loss: 0.0379, Reconstruction loss: 0.0377, KL loss: 0.0002
# Total loss: 0.0370, Reconstruction loss: 0.0368, KL loss: 0.0002
# Total loss: 0.0388, Reconstruction loss: 0.0385, KL loss: 0.0003
# Total loss: 0.0353, Reconstruction loss: 0.0352, KL loss: 0.0001
# Total loss: 0.0350, Reconstruction loss: 0.0348, KL loss: 0.0002
# Total loss: 0.0360, Reconstruction loss: 0.0359, KL loss: 0.0002
# Total loss: 0.0373, Reconstruction loss: 0.0371, KL loss: 0.0002
# Total loss: 0.0367, Reconstruction loss: 0.0365, KL loss: 0.0002
# Total loss: 0.0335, Reconstruction loss: 0.0334, KL loss: 0.0001
# Total loss: 0.0390, Reconstruction loss: 0.0388, KL loss: 0.0002
# Total loss: 0.0358, Reconstruction loss: 0.0357, KL loss: 0.0001
# Total loss: 0.0357, Reconstruction loss: 0.0355, KL loss: 0.0002
# Total loss: 0.0356, Reconstruction loss: 0.0355, KL loss: 0.0001
# Total loss: 0.0397, Reconstruction loss: 0.0395, KL loss: 0.0002
# Total loss: 0.0337, Reconstruction loss: 0.0335, KL loss: 0.0002
# Total loss: 0.0356, Reconstruction loss: 0.0354, KL loss: 0.0002
# Total loss: 0.0343, Reconstruction loss: 0.0342, KL loss: 0.0001
# Total loss: 0.0358, Reconstruction loss: 0.0356, KL loss: 0.0002
# Total loss: 0.0355, Reconstruction loss: 0.0353, KL loss: 0.0001
# Total loss: 0.0370, Reconstruction loss: 0.0368, KL loss: 0.0002
# Total loss: 0.0336, Reconstruction loss: 0.0334, KL loss: 0.0002
# Total loss: 0.0351, Reconstruction loss: 0.0349, KL loss: 0.0002
# Total loss: 0.0361, Reconstruction loss: 0.0360, KL loss: 0.0002
# Total loss: 0.0356, Reconstruction loss: 0.0354, KL loss: 0.0001
# Total loss: 0.0377, Reconstruction loss: 0.0375, KL loss: 0.0001
# Total loss: 0.0334, Reconstruction loss: 0.0333, KL loss: 0.0001
# Total loss: 0.0389, Reconstruction loss: 0.0387, KL loss: 0.0002
# Total loss: 0.0367, Reconstruction loss: 0.0364, KL loss: 0.0002
# Total loss: 0.0373, Reconstruction loss: 0.0371, KL loss: 0.0002
# Total loss: 0.0364, Reconstruction loss: 0.0362, KL loss: 0.0002
# Total loss: 0.0346, Reconstruction loss: 0.0344, KL loss: 0.0002
# Total loss: 0.0360, Reconstruction loss: 0.0358, KL loss: 0.0002
# Total loss: 0.0344, Reconstruction loss: 0.0343, KL loss: 0.0001
# Total loss: 0.0359, Reconstruction loss: 0.0358, KL loss: 0.0001
# Total loss: 0.0366, Reconstruction loss: 0.0365, KL loss: 0.0001
# Total loss: 0.0352, Reconstruction loss: 0.0351, KL loss: 0.0002
# Total loss: 0.0358, Reconstruction loss: 0.0356, KL loss: 0.0002
# Total loss: 0.0365, Reconstruction loss: 0.0364, KL loss: 0.0002
# Total loss: 0.0345, Reconstruction loss: 0.0344, KL loss: 0.0001
# Total loss: 0.0340, Reconstruction loss: 0.0339, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0360, KL loss: 0.0001
# Total loss: 0.0383, Reconstruction loss: 0.0382, KL loss: 0.0002
# Total loss: 0.0351, Reconstruction loss: 0.0350, KL loss: 0.0002
# Total loss: 0.0378, Reconstruction loss: 0.0377, KL loss: 0.0001
# Epoch 9/10
# Total loss: 0.0334, Reconstruction loss: 0.0333, KL loss: 0.0002
# Total loss: 0.0354, Reconstruction loss: 0.0352, KL loss: 0.0001
# Total loss: 0.0366, Reconstruction loss: 0.0365, KL loss: 0.0002
# Total loss: 0.0359, Reconstruction loss: 0.0358, KL loss: 0.0001
# Total loss: 0.0366, Reconstruction loss: 0.0366, KL loss: 0.0001
# Total loss: 0.0383, Reconstruction loss: 0.0382, KL loss: 0.0002
# Total loss: 0.0355, Reconstruction loss: 0.0354, KL loss: 0.0001
# Total loss: 0.0338, Reconstruction loss: 0.0336, KL loss: 0.0001
# Total loss: 0.0348, Reconstruction loss: 0.0346, KL loss: 0.0001
# Total loss: 0.0365, Reconstruction loss: 0.0363, KL loss: 0.0002
# Total loss: 0.0339, Reconstruction loss: 0.0338, KL loss: 0.0001
# Total loss: 0.0368, Reconstruction loss: 0.0366, KL loss: 0.0001
# Total loss: 0.0367, Reconstruction loss: 0.0365, KL loss: 0.0002
# Total loss: 0.0362, Reconstruction loss: 0.0361, KL loss: 0.0001
# Total loss: 0.0363, Reconstruction loss: 0.0362, KL loss: 0.0001
# Total loss: 0.0353, Reconstruction loss: 0.0351, KL loss: 0.0002
# Total loss: 0.0351, Reconstruction loss: 0.0350, KL loss: 0.0001
# Total loss: 0.0349, Reconstruction loss: 0.0347, KL loss: 0.0002
# Total loss: 0.0356, Reconstruction loss: 0.0355, KL loss: 0.0002
# Total loss: 0.0358, Reconstruction loss: 0.0356, KL loss: 0.0002
# Total loss: 0.0372, Reconstruction loss: 0.0371, KL loss: 0.0002
# Total loss: 0.0360, Reconstruction loss: 0.0359, KL loss: 0.0001
# Total loss: 0.0384, Reconstruction loss: 0.0382, KL loss: 0.0002
# Total loss: 0.0350, Reconstruction loss: 0.0349, KL loss: 0.0001
# Total loss: 0.0350, Reconstruction loss: 0.0349, KL loss: 0.0001
# Total loss: 0.0352, Reconstruction loss: 0.0351, KL loss: 0.0001
# Total loss: 0.0371, Reconstruction loss: 0.0369, KL loss: 0.0001
# Total loss: 0.0358, Reconstruction loss: 0.0357, KL loss: 0.0001
# Total loss: 0.0333, Reconstruction loss: 0.0332, KL loss: 0.0001
# Total loss: 0.0384, Reconstruction loss: 0.0383, KL loss: 0.0001
# Total loss: 0.0354, Reconstruction loss: 0.0353, KL loss: 0.0001
# Total loss: 0.0350, Reconstruction loss: 0.0349, KL loss: 0.0001
# Total loss: 0.0354, Reconstruction loss: 0.0353, KL loss: 0.0001
# Total loss: 0.0392, Reconstruction loss: 0.0391, KL loss: 0.0001
# Total loss: 0.0335, Reconstruction loss: 0.0334, KL loss: 0.0001
# Total loss: 0.0355, Reconstruction loss: 0.0353, KL loss: 0.0001
# Total loss: 0.0338, Reconstruction loss: 0.0337, KL loss: 0.0001
# Total loss: 0.0352, Reconstruction loss: 0.0351, KL loss: 0.0001
# Total loss: 0.0348, Reconstruction loss: 0.0347, KL loss: 0.0001
# Total loss: 0.0370, Reconstruction loss: 0.0369, KL loss: 0.0001
# Total loss: 0.0335, Reconstruction loss: 0.0333, KL loss: 0.0001
# Total loss: 0.0345, Reconstruction loss: 0.0343, KL loss: 0.0001
# Total loss: 0.0355, Reconstruction loss: 0.0354, KL loss: 0.0001
# Total loss: 0.0355, Reconstruction loss: 0.0354, KL loss: 0.0001
# Total loss: 0.0370, Reconstruction loss: 0.0369, KL loss: 0.0001
# Total loss: 0.0330, Reconstruction loss: 0.0329, KL loss: 0.0001
# Total loss: 0.0383, Reconstruction loss: 0.0382, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0359, KL loss: 0.0002
# Total loss: 0.0367, Reconstruction loss: 0.0366, KL loss: 0.0001
# Total loss: 0.0364, Reconstruction loss: 0.0363, KL loss: 0.0001
# Total loss: 0.0345, Reconstruction loss: 0.0344, KL loss: 0.0001
# Total loss: 0.0355, Reconstruction loss: 0.0353, KL loss: 0.0001
# Total loss: 0.0339, Reconstruction loss: 0.0338, KL loss: 0.0001
# Total loss: 0.0359, Reconstruction loss: 0.0359, KL loss: 0.0000
# Total loss: 0.0366, Reconstruction loss: 0.0365, KL loss: 0.0001
# Total loss: 0.0347, Reconstruction loss: 0.0345, KL loss: 0.0001
# Total loss: 0.0358, Reconstruction loss: 0.0357, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0360, KL loss: 0.0001
# Total loss: 0.0341, Reconstruction loss: 0.0340, KL loss: 0.0001
# Total loss: 0.0334, Reconstruction loss: 0.0334, KL loss: 0.0001
# Total loss: 0.0354, Reconstruction loss: 0.0354, KL loss: 0.0001
# Total loss: 0.0377, Reconstruction loss: 0.0376, KL loss: 0.0001
# Total loss: 0.0347, Reconstruction loss: 0.0346, KL loss: 0.0001
# Total loss: 0.0373, Reconstruction loss: 0.0372, KL loss: 0.0001
# Epoch 10/10
# Total loss: 0.0328, Reconstruction loss: 0.0327, KL loss: 0.0001
# Total loss: 0.0351, Reconstruction loss: 0.0350, KL loss: 0.0001
# Total loss: 0.0362, Reconstruction loss: 0.0361, KL loss: 0.0001
# Total loss: 0.0358, Reconstruction loss: 0.0357, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0361, KL loss: 0.0001
# Total loss: 0.0384, Reconstruction loss: 0.0383, KL loss: 0.0001
# Total loss: 0.0349, Reconstruction loss: 0.0348, KL loss: 0.0001
# Total loss: 0.0331, Reconstruction loss: 0.0330, KL loss: 0.0001
# Total loss: 0.0343, Reconstruction loss: 0.0342, KL loss: 0.0001
# Total loss: 0.0363, Reconstruction loss: 0.0362, KL loss: 0.0001
# Total loss: 0.0338, Reconstruction loss: 0.0337, KL loss: 0.0001
# Total loss: 0.0365, Reconstruction loss: 0.0364, KL loss: 0.0001
# Total loss: 0.0366, Reconstruction loss: 0.0364, KL loss: 0.0001
# Total loss: 0.0360, Reconstruction loss: 0.0359, KL loss: 0.0001
# Total loss: 0.0356, Reconstruction loss: 0.0356, KL loss: 0.0001
# Total loss: 0.0348, Reconstruction loss: 0.0347, KL loss: 0.0001
# Total loss: 0.0343, Reconstruction loss: 0.0342, KL loss: 0.0001
# Total loss: 0.0348, Reconstruction loss: 0.0347, KL loss: 0.0001
# Total loss: 0.0356, Reconstruction loss: 0.0355, KL loss: 0.0001
# Total loss: 0.0351, Reconstruction loss: 0.0350, KL loss: 0.0001
# Total loss: 0.0369, Reconstruction loss: 0.0368, KL loss: 0.0001
# Total loss: 0.0360, Reconstruction loss: 0.0359, KL loss: 0.0001
# Total loss: 0.0388, Reconstruction loss: 0.0386, KL loss: 0.0001
# Total loss: 0.0348, Reconstruction loss: 0.0348, KL loss: 0.0000
# Total loss: 0.0345, Reconstruction loss: 0.0344, KL loss: 0.0001
# Total loss: 0.0349, Reconstruction loss: 0.0349, KL loss: 0.0001
# Total loss: 0.0364, Reconstruction loss: 0.0363, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0360, KL loss: 0.0001
# Total loss: 0.0330, Reconstruction loss: 0.0330, KL loss: 0.0001
# Total loss: 0.0378, Reconstruction loss: 0.0377, KL loss: 0.0001
# Total loss: 0.0349, Reconstruction loss: 0.0348, KL loss: 0.0000
# Total loss: 0.0349, Reconstruction loss: 0.0348, KL loss: 0.0001
# Total loss: 0.0353, Reconstruction loss: 0.0352, KL loss: 0.0000
# Total loss: 0.0385, Reconstruction loss: 0.0384, KL loss: 0.0001
# Total loss: 0.0333, Reconstruction loss: 0.0332, KL loss: 0.0001
# Total loss: 0.0353, Reconstruction loss: 0.0352, KL loss: 0.0001
# Total loss: 0.0335, Reconstruction loss: 0.0335, KL loss: 0.0000
# Total loss: 0.0356, Reconstruction loss: 0.0355, KL loss: 0.0001
# Total loss: 0.0343, Reconstruction loss: 0.0342, KL loss: 0.0000
# Total loss: 0.0363, Reconstruction loss: 0.0362, KL loss: 0.0001
# Total loss: 0.0332, Reconstruction loss: 0.0331, KL loss: 0.0001
# Total loss: 0.0344, Reconstruction loss: 0.0343, KL loss: 0.0001
# Total loss: 0.0357, Reconstruction loss: 0.0357, KL loss: 0.0001
# Total loss: 0.0347, Reconstruction loss: 0.0347, KL loss: 0.0000
# Total loss: 0.0366, Reconstruction loss: 0.0366, KL loss: 0.0000
# Total loss: 0.0327, Reconstruction loss: 0.0326, KL loss: 0.0000
# Total loss: 0.0379, Reconstruction loss: 0.0379, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0360, KL loss: 0.0001
# Total loss: 0.0366, Reconstruction loss: 0.0365, KL loss: 0.0001
# Total loss: 0.0361, Reconstruction loss: 0.0361, KL loss: 0.0001
# Total loss: 0.0339, Reconstruction loss: 0.0338, KL loss: 0.0001
# Total loss: 0.0356, Reconstruction loss: 0.0355, KL loss: 0.0001
# Total loss: 0.0336, Reconstruction loss: 0.0336, KL loss: 0.0001
# Total loss: 0.0353, Reconstruction loss: 0.0352, KL loss: 0.0000
# Total loss: 0.0362, Reconstruction loss: 0.0361, KL loss: 0.0001
# Total loss: 0.0343, Reconstruction loss: 0.0342, KL loss: 0.0001
# Total loss: 0.0349, Reconstruction loss: 0.0348, KL loss: 0.0001
# Total loss: 0.0353, Reconstruction loss: 0.0352, KL loss: 0.0001
# Total loss: 0.0341, Reconstruction loss: 0.0340, KL loss: 0.0001
# Total loss: 0.0331, Reconstruction loss: 0.0330, KL loss: 0.0000
# Total loss: 0.0349, Reconstruction loss: 0.0348, KL loss: 0.0001
# Total loss: 0.0373, Reconstruction loss: 0.0372, KL loss: 0.0001
# Total loss: 0.0344, Reconstruction loss: 0.0344, KL loss: 0.0001
# Total loss: 0.0362, Reconstruction loss: 0.0361, KL loss: 0.0000

# %%
# Evaluate the trained model on the test dataset
test_loss = []
for batch_images, batch_color_ids, batch_binary_attributes in test_dataset:
    reconstructed_images, z_mean, z_log_var = cvae([batch_images, batch_color_ids, batch_binary_attributes])
    rec_loss = reconstruction_loss(batch_images, reconstructed_images)
    rec_loss = tf.reduce_mean(rec_loss)
    kl_loss = -0.5 * tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1)
    kl_loss = tf.reduce_mean(kl_loss)
    total_loss = rec_loss + kl_loss
    test_loss.append(total_loss)

test_loss = tf.reduce_mean(test_loss)
print(f"Test loss: {test_loss:.4f}")
# Out:
# Test loss: 0.0369

# %%
import matplotlib.pyplot as plt

def show(image_batch):
    plt.figure(figsize=(10,10))
    for n in range(4):
        ax = plt.subplot(1,4,n+1)
        plt.imshow(image_batch[n])
        plt.axis('off')
    plt.show()

for batch_images, batch_color_ids, batch_binary_attributes in test_dataset.take(2):
    reconstructed_images, _, _ = cvae([batch_images, batch_color_ids, batch_binary_attributes])
    show(batch_images)
    show(reconstructed_images)
