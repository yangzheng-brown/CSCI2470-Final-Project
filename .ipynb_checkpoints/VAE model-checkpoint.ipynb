# %%
####################read dataset#########################
import os
import random
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

image_folder = "data/img"
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith(".jpg")]
#image_files

######################split dataset#######################
random.seed(0)
random.shuffle(image_files)
total_images = len(image_files)
train_ratio = 0.8

train_files = image_files[:int(total_images * train_ratio)]
test_files = image_files[int(total_images * train_ratio):]
#print(train_files)
#print(test_files)

# %%
#Create a vocabulary dictionary that maps all the unique color tokens from your train and test data as keys to a unique integer value.
item_attr_data = pd.read_csv("data/item_attr_data_cleaned.csv")
color_unique = item_attr_data['clothes_color'].unique()
print("number of colors:",len(color_unique))
color_vocab = sorted(set(color_unique))
color_vocabulary = {w:i for i, w in enumerate(color_vocab)}
#print(color_vocabulary)
for i,j in enumerate(item_attr_data['clothes_color']):
    color_value = color_vocabulary[j]
    item_attr_data.loc[i, "clothes_color"] = color_value
# Out:
# number of colors: 759

# %%
###################train dataset label##########################
train_ids=[]
for train_index in train_files:
    parts = train_index.split('/')
    train_ids.append(parts[2][:-4])
    
train_labels = pd.DataFrame(columns=item_attr_data.columns)
train_labels = pd.concat([item_attr_data[item_attr_data['img_idx']==i] for i in train_ids], axis=0, ignore_index=True)
train_labels = train_labels.drop(columns=['index','img_idx'])
train_color = train_labels.pop('clothes_color')

train_color_np = train_color.to_numpy(dtype=np.int32)
train_labels_np = train_labels.to_numpy(dtype=np.float32)
train_labels_np = (train_labels_np + 1) / 2

###################test dataset label##########################
test_ids=[]
for test_index in test_files:
    parts = test_index.split('/')
    test_ids.append(parts[2][:-4])
    
test_labels = pd.DataFrame(columns=item_attr_data.columns)
test_labels = pd.concat([item_attr_data[item_attr_data['img_idx']==i] for i in test_ids], axis=0, ignore_index=True)
test_labels = test_labels.drop(columns=['index','img_idx'])
test_color = test_labels.pop('clothes_color')

test_color_np = test_color.to_numpy(dtype=np.int32)
test_labels_np = test_labels.to_numpy(dtype=np.float32)
test_labels_np = (test_labels_np + 1) / 2

# print(train_labels_np[:5])
# print(train_color_np[:5])

# %%
def load_image(image_file):
    image = tf.io.read_file(image_file)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (64, 64))
    image = tf.cast(image, tf.float32) / 255.0
    return image

# %%
batch_size = 100
train_dataset = tf.data.Dataset.from_tensor_slices(train_files)
train_dataset = train_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices(test_files)
test_dataset = test_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %%
train_color_ids_dataset = tf.data.Dataset.from_tensor_slices(train_color_np)
test_color_ids_dataset = tf.data.Dataset.from_tensor_slices(test_color_np)

train_binary_attributes_dataset = tf.data.Dataset.from_tensor_slices(train_labels_np)
test_binary_attributes_dataset = tf.data.Dataset.from_tensor_slices(test_labels_np)

train_dataset = tf.data.Dataset.zip((train_dataset, train_color_ids_dataset, train_binary_attributes_dataset))
test_dataset = tf.data.Dataset.zip((test_dataset, test_color_ids_dataset, test_binary_attributes_dataset))

train_dataset = train_dataset.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
print(test_dataset)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None), TensorSpec(shape=(None, 463), dtype=tf.float32, name=None))>

# %%
#################show the image####################
# Define a function to display a batch of images
def show_images(image_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.axis('off')
    plt.show()
    
# Get a batch of images from the train_dataset
for images, color_ids, binary_attributes in train_dataset.take(1):
    show_images(images)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.applications import VGG16
from tensorflow.keras import backend as K

# Hyperparameters
embedding_dimension = 16
latent_dimension = 256
num_colors = 759
num_binary_attributes = 463
input_shape = (64, 64, 3)

# Cloth color embedding layer
color_embedding = layers.Embedding(num_colors, embedding_dimension, name="color_embedding")

# Encoder
# def create_encoder(input_shape, num_attributes):
#     inputs = Input(shape=input_shape, name="encoder_input")
#     attr_inputs = Input(shape=(num_attributes,), name="attribute_input")
    
#     x = layers.Conv2D(32, kernel_size=3, strides=2, padding="same", activation="relu")(inputs)
#     x = layers.Conv2D(64, kernel_size=3, strides=2, padding="same", activation="relu")(x)
    
#     x = layers.Flatten()(x)
#     x = layers.Dense(latent_dimension, activation="relu")(x)
    
#     attr_x = layers.Dense(latent_dimension, activation="relu")(attr_inputs)
#     attr_x = layers.Dense(latent_dimension, activation="relu")(attr_x)
#     attr_x = layers.Dense(latent_dimension, activation="relu")(attr_x)
#     merged = layers.Concatenate()([x, attr_x])   
    
#     z_mean = layers.Dense(latent_dimension, name="z_mean")(merged)
#     z_log_var = layers.Dense(latent_dimension, name="z_log_var")(merged)
    
#     return Model([inputs, attr_inputs], [z_mean, z_log_var], name="encoder")

def create_vgg16_encoder(input_shape, num_attributes):
    inputs = Input(shape=input_shape, name="encoder_input")
    attr_inputs = Input(shape=(num_attributes,), name="attribute_input")
    
    # Use VGG16 as a feature extractor
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=input_shape)
    
    # Set VGG16 layers to non-trainable
    for layer in vgg16.layers:
        layer.trainable = False
    
    # Apply VGG16 to the input images
    x = vgg16(inputs)
    
    # Flatten and reduce the dimensionality of the VGG16 features
    x = layers.Flatten()(x)
    x = layers.Dense(latent_dimension, activation="relu")(x)
    
    attr_x = layers.Dense(latent_dimension, activation="relu")(attr_inputs)
    attr_x = layers.Dense(latent_dimension, activation="relu")(attr_x)
    
    merged = layers.Concatenate()([x, attr_x])
    
    z_mean = layers.Dense(latent_dimension, name="z_mean")(merged)
    z_log_var = layers.Dense(latent_dimension, name="z_log_var")(merged)
    
    return Model([inputs, attr_inputs], [z_mean, z_log_var], name="encoder")

def create_unet_decoder(latent_dimension, num_attributes):
    inputs = Input(shape=(latent_dimension + num_attributes,), name="decoder_input")

    x = layers.Dense(64 * 64 * 64, activation="relu")(inputs)
    x = layers.Reshape((64, 64, 64))(x)

    # Encoder part (contracting path)
    e1 = layers.Conv2D(64, kernel_size=3, strides=2, padding="same", activation="relu")(x)
    e2 = layers.Conv2D(128, kernel_size=3, strides=2, padding="same", activation="relu")(e1)

    # Decoder part (expanding path)
    d1 = layers.Conv2DTranspose(128, kernel_size=3, strides=2, padding="same", activation="relu")(e2)
    d1 = layers.Concatenate()([d1, e1])  # Skip connection
    d2 = layers.Conv2DTranspose(64, kernel_size=3, strides=2, padding="same", activation="relu")(d1)
    d2 = layers.Concatenate()([d2, x])  # Skip connection

    outputs = layers.Conv2DTranspose(3, kernel_size=3, padding="same", activation="sigmoid", name="decoder_output")(d2)

    return Model(inputs, outputs, name="decoder")

# # Decoder
# def create_decoder(latent_dimension, num_attributes):
#     inputs = Input(shape=(latent_dimension + num_attributes,), name="decoder_input")
    
#     x = layers.Dense(latent_dimension, activation="relu")(inputs)
#     x = layers.Dense(16 * 16 * 16, activation="relu")(x)
#     x = layers.Reshape((16, 16, 16))(x)
    
#     x = layers.Conv2DTranspose(64, kernel_size=3, strides=2, padding="same", activation="relu")(x)
#     x = layers.Conv2DTranspose(32, kernel_size=3, strides=2, padding="same", activation="relu")(x)
    
#     outputs = layers.Conv2DTranspose(3, kernel_size=3, padding="same", activation="sigmoid", name="decoder_output")(x)
    
#     return Model(inputs, outputs, name="decoder")

# CVAE Model
class CVAE(Model):
    def __init__(self, encoder, decoder, color_embedding, num_binary_attributes, **kwargs):
        super(CVAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.color_embedding = color_embedding
        self.num_binary_attributes = num_binary_attributes
    
    def call(self, inputs, training=False):
        images, color_ids, binary_attributes = inputs
        
        # Get color embeddings
        color_embeds = self.color_embedding(color_ids)
        
        # Concatenate color embeddings with binary attributes
        attribute_vector = layers.Concatenate(axis=-1)([color_embeds, binary_attributes])
        #attribute_vector = layers.Concatenate(axis=-1)([color_embeds])
        
        # Encode input images and attributes
        z_mean, z_log_var = self.encoder([images, attribute_vector])
        
        # Sample from the latent space
        batch_size = tf.shape(images)[0]
        epsilon = tf.random.normal(shape=(batch_size, latent_dimension))
        z = z_mean + tf.exp(0.5 * z_log_var) * epsilon
        
        # Concatenate latent vector with the attribute vector
        z_cond = layers.Concatenate(axis=-1)([z, attribute_vector])
        
        # Decode the conditioned latent vector
        reconstructed_images = self.decoder(z_cond)
        
        return reconstructed_images, z_mean, z_log_var

# Instantiate the encoder, decoder, and CVAE model
#encoder = create_encoder(input_shape, embedding_dimension + num_binary_attributes)
# decoder = create_decoder(latent_dimension, embedding_dimension + num_binary_attributes)
# cvae = CVAE(encoder, decoder, color_embedding, num_binary_attributes)
vgg16_encoder = create_vgg16_encoder(input_shape, embedding_dimension + num_binary_attributes)
unet_decoder = create_unet_decoder(latent_dimension, embedding_dimension + num_binary_attributes)
cvae = CVAE(vgg16_encoder, unet_decoder, color_embedding, num_binary_attributes)
#cvae = CVAE(encoder, unet_decoder, color_embedding, num_binary_attributes)
# encoder = create_encoder(input_shape, embedding_dimension)
# decoder = create_decoder(latent_dimension, embedding_dimension)
# cvae = CVAE(encoder, decoder, color_embedding, num_binary_attributes)

# Loss function and optimizer
reconstruction_loss = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# Custom training step
@tf.function
def train_step(images, color_ids, binary_attributes):
    beta = 0.1
    with tf.GradientTape() as tape:
        reconstructed_images, z_mean, z_log_var = cvae([images, color_ids, binary_attributes], training=True)
        
        # Calculate reconstruction loss
        rec_loss = reconstruction_loss(layers.Flatten()(images), layers.Flatten()(reconstructed_images))
        rec_loss *= input_shape[0] * input_shape[1] * input_shape[2]
        
        # Calculate KL divergence loss
        kl_loss = -0.5 * tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1)
        kl_loss = tf.reduce_mean(kl_loss)
        
        # Combine losses
        total_loss = rec_loss + beta * kl_loss
    
    # Calculate gradients and update model weights
    gradients = tape.gradient(total_loss, cvae.trainable_variables)
    optimizer.apply_gradients(zip(gradients, cvae.trainable_variables))
    
    return total_loss, rec_loss, kl_loss

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")
    
    for batch_images, batch_color_ids, batch_binary_attributes in train_dataset:
        total_loss, rec_loss, kl_loss = train_step(batch_images, batch_color_ids, batch_binary_attributes)
        print(f"Total loss: {total_loss:.4f}, Reconstruction loss: {rec_loss:.4f}, KL loss: {kl_loss:.4f}")
# Out:
# Epoch 1/10
# Total loss: 1893.4263, Reconstruction loss: 1893.0149, KL loss: 41.1436
# Total loss: 1907.8689, Reconstruction loss: 1907.4827, KL loss: 38.6265
# Total loss: 1829.6407, Reconstruction loss: 1829.2310, KL loss: 40.9808
# Total loss: 1782.8218, Reconstruction loss: 1782.3816, KL loss: 44.0203
# Total loss: 1759.4164, Reconstruction loss: 1758.9338, KL loss: 48.2529
# Total loss: 1695.3890, Reconstruction loss: 1694.8679, KL loss: 52.1086
# Total loss: 1654.5159, Reconstruction loss: 1653.9470, KL loss: 56.8828
# Total loss: 1564.8325, Reconstruction loss: 1564.2078, KL loss: 62.4753
# Total loss: 1488.9773, Reconstruction loss: 1488.2993, KL loss: 67.8026
# Total loss: 1426.3627, Reconstruction loss: 1425.6221, KL loss: 74.0554
# Total loss: 1345.3107, Reconstruction loss: 1344.4888, KL loss: 82.1951
# Total loss: 1258.0885, Reconstruction loss: 1257.1807, KL loss: 90.7854
# Total loss: 1145.3123, Reconstruction loss: 1144.2928, KL loss: 101.9394
# Total loss: 1043.4592, Reconstruction loss: 1042.3196, KL loss: 113.9640
# Total loss: 976.8960, Reconstruction loss: 975.6898, KL loss: 120.6224
# Total loss: 873.9657, Reconstruction loss: 872.6195, KL loss: 134.6184
# Total loss: 804.0154, Reconstruction loss: 802.5634, KL loss: 145.2089
# Total loss: 720.2453, Reconstruction loss: 718.6632, KL loss: 158.2115
# Total loss: 670.8404, Reconstruction loss: 669.1061, KL loss: 173.4325
# Total loss: 607.7210, Reconstruction loss: 605.8317, KL loss: 188.9306
# Total loss: 588.2466, Reconstruction loss: 586.1455, KL loss: 210.1159
# Total loss: 573.8250, Reconstruction loss: 571.5466, KL loss: 227.8304
# Total loss: 573.8209, Reconstruction loss: 571.4504, KL loss: 237.0468
# Total loss: 504.2713, Reconstruction loss: 501.6612, KL loss: 261.0092
# Total loss: 493.7441, Reconstruction loss: 491.0343, KL loss: 270.9835
# Total loss: 522.6942, Reconstruction loss: 519.7321, KL loss: 296.2091
# Total loss: 536.7675, Reconstruction loss: 533.7943, KL loss: 297.3213
# Total loss: 522.8442, Reconstruction loss: 519.7037, KL loss: 314.0467
# Total loss: 473.3007, Reconstruction loss: 470.0651, KL loss: 323.5550
# Total loss: 556.3856, Reconstruction loss: 552.9845, KL loss: 340.1080
# Total loss: 486.9671, Reconstruction loss: 483.6792, KL loss: 328.7911
# Total loss: 499.3271, Reconstruction loss: 495.9691, KL loss: 335.7957
# Total loss: 498.4194, Reconstruction loss: 495.0724, KL loss: 334.6970
# Total loss: 547.5897, Reconstruction loss: 544.1307, KL loss: 345.8989
# Total loss: 463.2090, Reconstruction loss: 459.8101, KL loss: 339.8922
# Total loss: 504.6705, Reconstruction loss: 501.2332, KL loss: 343.7300
# Total loss: 476.0014, Reconstruction loss: 472.5643, KL loss: 343.7039
# Total loss: 504.9845, Reconstruction loss: 501.5783, KL loss: 340.6129
# Total loss: 466.9948, Reconstruction loss: 463.6456, KL loss: 334.9252
# Total loss: 517.6002, Reconstruction loss: 514.1978, KL loss: 340.2408
# Total loss: 460.2845, Reconstruction loss: 456.9112, KL loss: 337.3349
# Total loss: 480.3906, Reconstruction loss: 477.2281, KL loss: 316.2579
# Total loss: 476.6342, Reconstruction loss: 473.3454, KL loss: 328.8795
# Total loss: 471.8953, Reconstruction loss: 468.6593, KL loss: 323.6017
# Total loss: 509.0906, Reconstruction loss: 505.8721, KL loss: 321.8516
# Total loss: 454.0917, Reconstruction loss: 450.8555, KL loss: 323.6195
# Total loss: 515.2353, Reconstruction loss: 512.1151, KL loss: 312.0187
# Total loss: 498.5614, Reconstruction loss: 495.5179, KL loss: 304.3501
# Total loss: 496.5081, Reconstruction loss: 493.4540, KL loss: 305.4177
# Total loss: 490.0332, Reconstruction loss: 487.0912, KL loss: 294.2047
# Total loss: 455.9446, Reconstruction loss: 452.9447, KL loss: 299.9912
# Total loss: 468.6722, Reconstruction loss: 465.8038, KL loss: 286.8451
# Total loss: 461.1870, Reconstruction loss: 458.3325, KL loss: 285.4486
# Total loss: 483.8044, Reconstruction loss: 480.9410, KL loss: 286.3409
# Total loss: 484.5508, Reconstruction loss: 481.7021, KL loss: 284.8697
# Total loss: 461.4537, Reconstruction loss: 458.7165, KL loss: 273.7288
# Total loss: 474.1461, Reconstruction loss: 471.4145, KL loss: 273.1561
# Total loss: 483.2680, Reconstruction loss: 480.5232, KL loss: 274.4759
# Total loss: 449.7253, Reconstruction loss: 447.1285, KL loss: 259.6856
# Total loss: 438.8725, Reconstruction loss: 436.2072, KL loss: 266.5343
# Total loss: 467.1513, Reconstruction loss: 464.4298, KL loss: 272.1488
# Total loss: 497.0687, Reconstruction loss: 494.4834, KL loss: 258.5346
# Total loss: 464.3222, Reconstruction loss: 461.7031, KL loss: 261.9086
# Total loss: 499.0509, Reconstruction loss: 496.4569, KL loss: 259.3990
# Epoch 2/10
# Total loss: 436.6210, Reconstruction loss: 434.0905, KL loss: 253.0525
# Total loss: 455.4987, Reconstruction loss: 452.9788, KL loss: 251.9909
# Total loss: 474.8628, Reconstruction loss: 472.3706, KL loss: 249.2133
# Total loss: 458.2197, Reconstruction loss: 455.7422, KL loss: 247.7445
# Total loss: 480.7881, Reconstruction loss: 478.3501, KL loss: 243.8006
# Total loss: 487.0057, Reconstruction loss: 484.5682, KL loss: 243.7457
# Total loss: 458.7208, Reconstruction loss: 456.3191, KL loss: 240.1740
# Total loss: 430.2061, Reconstruction loss: 427.8002, KL loss: 240.5946
# Total loss: 457.1557, Reconstruction loss: 454.7661, KL loss: 238.9545
# Total loss: 478.5307, Reconstruction loss: 476.1367, KL loss: 239.4004
# Total loss: 431.2354, Reconstruction loss: 428.8120, KL loss: 242.3431
# Total loss: 464.2275, Reconstruction loss: 461.8160, KL loss: 241.1486
# Total loss: 474.6203, Reconstruction loss: 472.1511, KL loss: 246.9216
# Total loss: 459.9283, Reconstruction loss: 457.4325, KL loss: 249.5828
# Total loss: 459.6770, Reconstruction loss: 457.2566, KL loss: 242.0384
# Total loss: 450.2184, Reconstruction loss: 447.7523, KL loss: 246.6090
# Total loss: 447.5246, Reconstruction loss: 445.0823, KL loss: 244.2307
# Total loss: 446.8840, Reconstruction loss: 444.4636, KL loss: 242.0425
# Total loss: 456.3850, Reconstruction loss: 453.9555, KL loss: 242.9435
# Total loss: 452.8927, Reconstruction loss: 450.4930, KL loss: 239.9668
# Total loss: 464.4066, Reconstruction loss: 461.9621, KL loss: 244.4448
# Total loss: 462.1413, Reconstruction loss: 459.7098, KL loss: 243.1490
# Total loss: 493.8885, Reconstruction loss: 491.5212, KL loss: 236.7386
# Total loss: 435.6419, Reconstruction loss: 433.2033, KL loss: 243.8573
# Total loss: 440.1342, Reconstruction loss: 437.7273, KL loss: 240.6875
# Total loss: 449.7229, Reconstruction loss: 447.2863, KL loss: 243.6659
# Total loss: 470.5236, Reconstruction loss: 468.1513, KL loss: 237.2319
# Total loss: 457.5916, Reconstruction loss: 455.2119, KL loss: 237.9731
# Total loss: 422.5681, Reconstruction loss: 420.1371, KL loss: 243.0934
# Total loss: 484.3040, Reconstruction loss: 481.8863, KL loss: 241.7703
# Total loss: 435.8336, Reconstruction loss: 433.4649, KL loss: 236.8693
# Total loss: 442.7362, Reconstruction loss: 440.3519, KL loss: 238.4344
# Total loss: 452.3981, Reconstruction loss: 450.0433, KL loss: 235.4830
# Total loss: 485.4725, Reconstruction loss: 483.1412, KL loss: 233.1346
# Total loss: 419.6160, Reconstruction loss: 417.2256, KL loss: 239.0320
# Total loss: 447.4987, Reconstruction loss: 445.1099, KL loss: 238.8760
# Total loss: 430.6834, Reconstruction loss: 428.2857, KL loss: 239.7714
# Total loss: 444.7632, Reconstruction loss: 442.3878, KL loss: 237.5391
# Total loss: 421.2302, Reconstruction loss: 418.8639, KL loss: 236.6346
# Total loss: 464.5951, Reconstruction loss: 462.1461, KL loss: 244.9003
# Total loss: 418.4807, Reconstruction loss: 416.0475, KL loss: 243.3168
# Total loss: 440.8453, Reconstruction loss: 438.5258, KL loss: 231.9557
# Total loss: 442.6413, Reconstruction loss: 440.2589, KL loss: 238.2449
# Total loss: 429.0783, Reconstruction loss: 426.6995, KL loss: 237.8761
# Total loss: 463.2710, Reconstruction loss: 460.8703, KL loss: 240.0666
# Total loss: 410.6633, Reconstruction loss: 408.2636, KL loss: 239.9651
# Total loss: 474.1573, Reconstruction loss: 471.7955, KL loss: 236.1828
# Total loss: 454.9108, Reconstruction loss: 452.6276, KL loss: 228.3227
# Total loss: 452.0034, Reconstruction loss: 449.6351, KL loss: 236.8306
# Total loss: 447.9283, Reconstruction loss: 445.6343, KL loss: 229.3957
# Total loss: 415.8631, Reconstruction loss: 413.5257, KL loss: 233.7439
# Total loss: 429.4028, Reconstruction loss: 427.1298, KL loss: 227.3023
# Total loss: 419.1445, Reconstruction loss: 416.8755, KL loss: 226.9005
# Total loss: 438.7153, Reconstruction loss: 436.4401, KL loss: 227.5261
# Total loss: 446.2751, Reconstruction loss: 443.9684, KL loss: 230.6699
# Total loss: 414.4129, Reconstruction loss: 412.1454, KL loss: 226.7529
# Total loss: 424.9257, Reconstruction loss: 422.6340, KL loss: 229.1750
# Total loss: 433.6692, Reconstruction loss: 431.3617, KL loss: 230.7487
# Total loss: 409.2297, Reconstruction loss: 407.0331, KL loss: 219.6652
# Total loss: 396.8318, Reconstruction loss: 394.4932, KL loss: 233.8561
# Total loss: 419.3499, Reconstruction loss: 417.0025, KL loss: 234.7457
# Total loss: 452.9046, Reconstruction loss: 450.6281, KL loss: 227.6459
# Total loss: 414.9608, Reconstruction loss: 412.6498, KL loss: 231.1032
# Total loss: 465.8088, Reconstruction loss: 463.5770, KL loss: 223.1785
# Epoch 3/10
# Total loss: 393.6840, Reconstruction loss: 391.3998, KL loss: 228.4237
# Total loss: 410.4901, Reconstruction loss: 408.2365, KL loss: 225.3574
# Total loss: 432.8289, Reconstruction loss: 430.6080, KL loss: 222.0932
# Total loss: 426.4161, Reconstruction loss: 424.1396, KL loss: 227.6465
# Total loss: 432.1450, Reconstruction loss: 429.9098, KL loss: 223.5170
# Total loss: 440.2764, Reconstruction loss: 438.0293, KL loss: 224.7072
# Total loss: 410.4851, Reconstruction loss: 408.2544, KL loss: 223.0646
# Total loss: 385.7247, Reconstruction loss: 383.4832, KL loss: 224.1502
# Total loss: 403.5092, Reconstruction loss: 401.2498, KL loss: 225.9459
# Total loss: 421.9657, Reconstruction loss: 419.6896, KL loss: 227.6042
# Total loss: 395.2075, Reconstruction loss: 392.9088, KL loss: 229.8640
# Total loss: 412.3874, Reconstruction loss: 410.1089, KL loss: 227.8478
# Total loss: 431.9141, Reconstruction loss: 429.6678, KL loss: 224.6273
# Total loss: 417.0326, Reconstruction loss: 414.7982, KL loss: 223.4341
# Total loss: 425.8934, Reconstruction loss: 423.6884, KL loss: 220.4971
# Total loss: 409.2934, Reconstruction loss: 407.0306, KL loss: 226.2790
# Total loss: 400.2357, Reconstruction loss: 398.0231, KL loss: 221.2595
# Total loss: 406.7199, Reconstruction loss: 404.5357, KL loss: 218.4174
# Total loss: 418.1524, Reconstruction loss: 415.9696, KL loss: 218.2812
# Total loss: 411.1679, Reconstruction loss: 409.0455, KL loss: 212.2417
# Total loss: 427.5073, Reconstruction loss: 425.2955, KL loss: 221.1783
# Total loss: 415.9683, Reconstruction loss: 413.8018, KL loss: 216.6507
# Total loss: 440.8592, Reconstruction loss: 438.7415, KL loss: 211.7716
# Total loss: 392.9324, Reconstruction loss: 390.7279, KL loss: 220.4494
# Total loss: 403.0406, Reconstruction loss: 400.8566, KL loss: 218.4067
# Total loss: 397.0075, Reconstruction loss: 394.8262, KL loss: 218.1378
# Total loss: 417.9649, Reconstruction loss: 415.8181, KL loss: 214.6729
# Total loss: 417.4173, Reconstruction loss: 415.2791, KL loss: 213.8217
# Total loss: 372.3891, Reconstruction loss: 370.1825, KL loss: 220.6636
# Total loss: 438.5111, Reconstruction loss: 436.3901, KL loss: 212.1003
# Total loss: 398.2765, Reconstruction loss: 396.1375, KL loss: 213.9009
# Total loss: 396.9200, Reconstruction loss: 394.7515, KL loss: 216.8525
# Total loss: 407.0300, Reconstruction loss: 404.8889, KL loss: 214.1090
# Total loss: 445.9150, Reconstruction loss: 443.8060, KL loss: 210.9053
# Total loss: 381.1479, Reconstruction loss: 378.9624, KL loss: 218.5531
# Total loss: 406.0836, Reconstruction loss: 403.9026, KL loss: 218.1011
# Total loss: 391.3653, Reconstruction loss: 389.2129, KL loss: 215.2340
# Total loss: 399.7118, Reconstruction loss: 397.5707, KL loss: 214.1094
# Total loss: 375.1371, Reconstruction loss: 373.0209, KL loss: 211.6131
# Total loss: 420.9018, Reconstruction loss: 418.7275, KL loss: 217.4314
# Total loss: 386.8848, Reconstruction loss: 384.7542, KL loss: 213.0616
# Total loss: 398.0435, Reconstruction loss: 396.0219, KL loss: 202.1693
# Total loss: 411.0906, Reconstruction loss: 409.0339, KL loss: 205.6704
# Total loss: 385.5486, Reconstruction loss: 383.5292, KL loss: 201.9450
# Total loss: 420.3542, Reconstruction loss: 418.3007, KL loss: 205.3459
# Total loss: 371.4408, Reconstruction loss: 369.3767, KL loss: 206.4093
# Total loss: 435.8120, Reconstruction loss: 433.7498, KL loss: 206.2126
# Total loss: 412.0585, Reconstruction loss: 410.0660, KL loss: 199.2479
# Total loss: 409.0395, Reconstruction loss: 406.9751, KL loss: 206.4413
# Total loss: 405.8593, Reconstruction loss: 403.8533, KL loss: 200.5968
# Total loss: 381.6121, Reconstruction loss: 379.5765, KL loss: 203.5545
# Total loss: 398.3094, Reconstruction loss: 396.3273, KL loss: 198.2087
# Total loss: 382.6141, Reconstruction loss: 380.6416, KL loss: 197.2470
# Total loss: 400.6103, Reconstruction loss: 398.6306, KL loss: 197.9748
# Total loss: 410.5911, Reconstruction loss: 408.5767, KL loss: 201.4400
# Total loss: 372.6418, Reconstruction loss: 370.6660, KL loss: 197.5763
# Total loss: 378.7467, Reconstruction loss: 376.7660, KL loss: 198.0692
# Total loss: 385.5958, Reconstruction loss: 383.5964, KL loss: 199.9400
# Total loss: 381.4335, Reconstruction loss: 379.5616, KL loss: 187.1844
# Total loss: 365.4275, Reconstruction loss: 363.4243, KL loss: 200.3219
# Total loss: 379.2650, Reconstruction loss: 377.2461, KL loss: 201.8883
# Total loss: 404.4883, Reconstruction loss: 402.5510, KL loss: 193.7342
# Total loss: 379.3221, Reconstruction loss: 377.3796, KL loss: 194.2401
# Total loss: 435.0153, Reconstruction loss: 433.1518, KL loss: 186.3475
# Epoch 4/10
# Total loss: 358.7879, Reconstruction loss: 356.8594, KL loss: 192.8523
# Total loss: 375.8492, Reconstruction loss: 373.9399, KL loss: 190.9304
# Total loss: 393.1701, Reconstruction loss: 391.3108, KL loss: 185.9273
# Total loss: 399.4696, Reconstruction loss: 397.5814, KL loss: 188.8262
# Total loss: 399.3806, Reconstruction loss: 397.5163, KL loss: 186.4261
# Total loss: 400.7365, Reconstruction loss: 398.8690, KL loss: 186.7580
# Total loss: 374.2928, Reconstruction loss: 372.4253, KL loss: 186.7530
# Total loss: 350.1734, Reconstruction loss: 348.2968, KL loss: 187.6644
# Total loss: 372.5924, Reconstruction loss: 370.7055, KL loss: 188.6958
# Total loss: 385.9003, Reconstruction loss: 384.0090, KL loss: 189.1244
# Total loss: 366.6027, Reconstruction loss: 364.7020, KL loss: 190.0705
# Total loss: 385.3752, Reconstruction loss: 383.4828, KL loss: 189.2377
# Total loss: 399.1232, Reconstruction loss: 397.2701, KL loss: 185.3087
# Total loss: 375.9650, Reconstruction loss: 374.1408, KL loss: 182.4223
# Total loss: 399.5535, Reconstruction loss: 397.7361, KL loss: 181.7424
# Total loss: 384.7410, Reconstruction loss: 382.8939, KL loss: 184.7048
# Total loss: 360.6300, Reconstruction loss: 358.7981, KL loss: 183.1864
# Total loss: 364.3097, Reconstruction loss: 362.4728, KL loss: 183.6878
# Total loss: 382.1410, Reconstruction loss: 380.2880, KL loss: 185.3017
# Total loss: 376.8662, Reconstruction loss: 375.0698, KL loss: 179.6399
# Total loss: 393.0608, Reconstruction loss: 391.1906, KL loss: 187.0188
# Total loss: 374.6895, Reconstruction loss: 372.8245, KL loss: 186.4952
# Total loss: 402.4397, Reconstruction loss: 400.6844, KL loss: 175.5287
# Total loss: 361.2896, Reconstruction loss: 359.4602, KL loss: 182.9328
# Total loss: 361.3513, Reconstruction loss: 359.5439, KL loss: 180.7390
# Total loss: 353.2831, Reconstruction loss: 351.4543, KL loss: 182.8855
# Total loss: 380.4523, Reconstruction loss: 378.6271, KL loss: 182.5159
# Total loss: 384.5876, Reconstruction loss: 382.7567, KL loss: 183.0862
# Total loss: 336.4863, Reconstruction loss: 334.6325, KL loss: 185.3796
# Total loss: 395.9426, Reconstruction loss: 394.1297, KL loss: 181.2898
# Total loss: 359.8598, Reconstruction loss: 358.0558, KL loss: 180.3965
# Total loss: 359.6125, Reconstruction loss: 357.7896, KL loss: 182.2938
# Total loss: 361.4718, Reconstruction loss: 359.6845, KL loss: 178.7273
# Total loss: 397.9957, Reconstruction loss: 396.2099, KL loss: 178.5759
# Total loss: 343.6759, Reconstruction loss: 341.8615, KL loss: 181.4492
# Total loss: 361.5719, Reconstruction loss: 359.7648, KL loss: 180.7149
# Total loss: 349.0809, Reconstruction loss: 347.2868, KL loss: 179.4051
# Total loss: 345.9083, Reconstruction loss: 344.1229, KL loss: 178.5409
# Total loss: 343.4090, Reconstruction loss: 341.6469, KL loss: 176.2134
# Total loss: 365.7744, Reconstruction loss: 363.9568, KL loss: 181.7562
# Total loss: 338.0057, Reconstruction loss: 336.2027, KL loss: 180.3017
# Total loss: 348.9137, Reconstruction loss: 347.1769, KL loss: 173.6859
# Total loss: 365.0904, Reconstruction loss: 363.2940, KL loss: 179.6396
# Total loss: 341.3088, Reconstruction loss: 339.5527, KL loss: 175.6028
# Total loss: 362.1226, Reconstruction loss: 360.3351, KL loss: 178.7469
# Total loss: 335.6576, Reconstruction loss: 333.8518, KL loss: 180.5781
# Total loss: 370.9424, Reconstruction loss: 369.1380, KL loss: 180.4332
# Total loss: 357.2964, Reconstruction loss: 355.5547, KL loss: 174.1702
# Total loss: 358.7658, Reconstruction loss: 356.9957, KL loss: 177.0144
# Total loss: 354.2604, Reconstruction loss: 352.5152, KL loss: 174.5257
# Total loss: 331.6492, Reconstruction loss: 329.8672, KL loss: 178.1966
# Total loss: 340.1794, Reconstruction loss: 338.4264, KL loss: 175.3013
# Total loss: 339.6459, Reconstruction loss: 337.8963, KL loss: 174.9620
# Total loss: 353.8997, Reconstruction loss: 352.1158, KL loss: 178.3880
# Total loss: 355.8938, Reconstruction loss: 354.0705, KL loss: 182.3260
# Total loss: 320.3651, Reconstruction loss: 318.5854, KL loss: 177.9695
# Total loss: 326.4584, Reconstruction loss: 324.6710, KL loss: 178.7451
# Total loss: 326.3569, Reconstruction loss: 324.5357, KL loss: 182.1200
# Total loss: 330.2703, Reconstruction loss: 328.5534, KL loss: 171.6846
# Total loss: 322.5241, Reconstruction loss: 320.7046, KL loss: 181.9468
# Total loss: 329.1794, Reconstruction loss: 327.3319, KL loss: 184.7529
# Total loss: 344.4688, Reconstruction loss: 342.6977, KL loss: 177.1096
# Total loss: 333.6796, Reconstruction loss: 331.8929, KL loss: 178.6685
# Total loss: 362.1255, Reconstruction loss: 360.3746, KL loss: 175.0968
# Epoch 5/10
# Total loss: 314.8463, Reconstruction loss: 313.0264, KL loss: 181.9955
# Total loss: 326.0053, Reconstruction loss: 324.1721, KL loss: 183.3211
# Total loss: 343.6947, Reconstruction loss: 341.9001, KL loss: 179.4615
# Total loss: 347.4493, Reconstruction loss: 345.6416, KL loss: 180.7684
# Total loss: 343.3640, Reconstruction loss: 341.5740, KL loss: 178.9903
# Total loss: 341.1000, Reconstruction loss: 339.2932, KL loss: 180.6818
# Total loss: 320.3118, Reconstruction loss: 318.5084, KL loss: 180.3402
# Total loss: 308.9657, Reconstruction loss: 307.1400, KL loss: 182.5747
# Total loss: 323.6452, Reconstruction loss: 321.7983, KL loss: 184.6957
# Total loss: 332.6414, Reconstruction loss: 330.7753, KL loss: 186.6085
# Total loss: 325.7888, Reconstruction loss: 323.9178, KL loss: 187.0940
# Total loss: 335.1061, Reconstruction loss: 333.2397, KL loss: 186.6468
# Total loss: 349.3454, Reconstruction loss: 347.4965, KL loss: 184.8900
# Total loss: 330.5169, Reconstruction loss: 328.6800, KL loss: 183.6972
# Total loss: 348.6459, Reconstruction loss: 346.8084, KL loss: 183.7432
# Total loss: 327.9650, Reconstruction loss: 326.0884, KL loss: 187.6554
# Total loss: 312.8073, Reconstruction loss: 310.9081, KL loss: 189.9158
# Total loss: 319.6100, Reconstruction loss: 317.6941, KL loss: 191.5896
# Total loss: 336.5842, Reconstruction loss: 334.6630, KL loss: 192.1187
# Total loss: 325.5401, Reconstruction loss: 323.6791, KL loss: 186.1023
# Total loss: 344.0306, Reconstruction loss: 342.1184, KL loss: 191.2129
# Total loss: 325.3012, Reconstruction loss: 323.3745, KL loss: 192.6657
# Total loss: 351.6114, Reconstruction loss: 349.7949, KL loss: 181.6528
# Total loss: 316.8753, Reconstruction loss: 314.9680, KL loss: 190.7331
# Total loss: 315.7169, Reconstruction loss: 313.8000, KL loss: 191.6894
# Total loss: 314.9078, Reconstruction loss: 312.9499, KL loss: 195.7933
# Total loss: 336.1779, Reconstruction loss: 334.2239, KL loss: 195.3960
# Total loss: 341.2433, Reconstruction loss: 339.2746, KL loss: 196.8651
# Total loss: 300.2039, Reconstruction loss: 298.2209, KL loss: 198.3057
# Total loss: 341.5008, Reconstruction loss: 339.5382, KL loss: 196.2600
# Total loss: 319.2763, Reconstruction loss: 317.3306, KL loss: 194.5665
# Total loss: 322.1429, Reconstruction loss: 320.1680, KL loss: 197.4871
# Total loss: 315.6479, Reconstruction loss: 313.6991, KL loss: 194.8781
# Total loss: 349.8031, Reconstruction loss: 347.8471, KL loss: 195.6014
# Total loss: 312.2075, Reconstruction loss: 310.2103, KL loss: 199.7220
# Total loss: 319.8462, Reconstruction loss: 317.8508, KL loss: 199.5352
# Total loss: 311.5800, Reconstruction loss: 309.5800, KL loss: 200.0009
# Total loss: 309.8706, Reconstruction loss: 307.8691, KL loss: 200.1477
# Total loss: 308.4408, Reconstruction loss: 306.4595, KL loss: 198.1328
# Total loss: 323.5273, Reconstruction loss: 321.4775, KL loss: 204.9813
# Total loss: 305.2403, Reconstruction loss: 303.1815, KL loss: 205.8792
# Total loss: 316.6727, Reconstruction loss: 314.6852, KL loss: 198.7430
# Total loss: 320.0933, Reconstruction loss: 318.0407, KL loss: 205.2612
# Total loss: 301.8253, Reconstruction loss: 299.8063, KL loss: 201.9027
# Total loss: 320.2552, Reconstruction loss: 318.2015, KL loss: 205.3735
# Total loss: 299.8655, Reconstruction loss: 297.7813, KL loss: 208.4200
# Total loss: 335.8614, Reconstruction loss: 333.7668, KL loss: 209.4543
# Total loss: 320.0780, Reconstruction loss: 318.0362, KL loss: 204.1853
# Total loss: 322.0657, Reconstruction loss: 319.9733, KL loss: 209.2439
# Total loss: 314.7015, Reconstruction loss: 312.6357, KL loss: 206.5843
# Total loss: 304.8635, Reconstruction loss: 302.7566, KL loss: 210.6920
# Total loss: 308.4744, Reconstruction loss: 306.4042, KL loss: 207.0138
# Total loss: 307.7698, Reconstruction loss: 305.7089, KL loss: 206.0889
# Total loss: 319.1992, Reconstruction loss: 317.0911, KL loss: 210.8029
# Total loss: 320.5677, Reconstruction loss: 318.4064, KL loss: 216.1328
# Total loss: 292.7480, Reconstruction loss: 290.6248, KL loss: 212.3242
# Total loss: 295.1808, Reconstruction loss: 293.0424, KL loss: 213.8371
# Total loss: 294.7191, Reconstruction loss: 292.5402, KL loss: 217.8899
# Total loss: 301.2892, Reconstruction loss: 299.2064, KL loss: 208.2843
# Total loss: 290.0731, Reconstruction loss: 287.8810, KL loss: 219.2086
# Total loss: 299.1076, Reconstruction loss: 296.8766, KL loss: 223.1026
# Total loss: 313.2822, Reconstruction loss: 311.1335, KL loss: 214.8766
# Total loss: 308.5446, Reconstruction loss: 306.3702, KL loss: 217.4416
# Total loss: 319.7649, Reconstruction loss: 317.6314, KL loss: 213.3492
# Epoch 6/10
# Total loss: 291.5639, Reconstruction loss: 289.3591, KL loss: 220.4790
# Total loss: 298.9311, Reconstruction loss: 296.7082, KL loss: 222.2926
# Total loss: 305.3716, Reconstruction loss: 303.1818, KL loss: 218.9839
# Total loss: 318.4113, Reconstruction loss: 316.2084, KL loss: 220.2871
# Total loss: 311.5538, Reconstruction loss: 309.3664, KL loss: 218.7384
# Total loss: 306.3107, Reconstruction loss: 304.1028, KL loss: 220.7829
# Total loss: 294.3253, Reconstruction loss: 292.1198, KL loss: 220.5402
# Total loss: 288.0176, Reconstruction loss: 285.7869, KL loss: 223.0734
# Total loss: 299.1692, Reconstruction loss: 296.9161, KL loss: 225.3157
# Total loss: 304.6921, Reconstruction loss: 302.4250, KL loss: 226.7123
# Total loss: 298.5491, Reconstruction loss: 296.2771, KL loss: 227.2001
# Total loss: 306.7906, Reconstruction loss: 304.5229, KL loss: 226.7725
# Total loss: 319.8436, Reconstruction loss: 317.5853, KL loss: 225.8322
# Total loss: 301.6585, Reconstruction loss: 299.4036, KL loss: 225.4872
# Total loss: 315.4748, Reconstruction loss: 313.2188, KL loss: 225.6008
# Total loss: 299.7561, Reconstruction loss: 297.4602, KL loss: 229.5860
# Total loss: 284.7803, Reconstruction loss: 282.4594, KL loss: 232.0962
# Total loss: 294.6306, Reconstruction loss: 292.3035, KL loss: 232.7016
# Total loss: 312.0601, Reconstruction loss: 309.7350, KL loss: 232.5035
# Total loss: 294.3700, Reconstruction loss: 292.1094, KL loss: 226.0586
# Total loss: 318.1317, Reconstruction loss: 315.8163, KL loss: 231.5497
# Total loss: 302.8608, Reconstruction loss: 300.5123, KL loss: 234.8513
# Total loss: 311.1528, Reconstruction loss: 308.9136, KL loss: 223.9160
# Total loss: 283.6522, Reconstruction loss: 281.3072, KL loss: 234.5029
# Total loss: 287.2265, Reconstruction loss: 284.8719, KL loss: 235.4568
# Total loss: 287.6157, Reconstruction loss: 285.2281, KL loss: 238.7638
# Total loss: 304.7016, Reconstruction loss: 302.3380, KL loss: 236.3634
# Total loss: 313.0212, Reconstruction loss: 310.6454, KL loss: 237.5736
# Total loss: 277.9976, Reconstruction loss: 275.6082, KL loss: 238.9410
# Total loss: 315.6367, Reconstruction loss: 313.2556, KL loss: 238.1133
# Total loss: 293.8004, Reconstruction loss: 291.4401, KL loss: 236.0296
# Total loss: 298.0443, Reconstruction loss: 295.6467, KL loss: 239.7648
# Total loss: 290.7489, Reconstruction loss: 288.3749, KL loss: 237.4019
# Total loss: 320.5177, Reconstruction loss: 318.1356, KL loss: 238.2097
# Total loss: 288.1125, Reconstruction loss: 285.6924, KL loss: 242.0126
# Total loss: 296.5374, Reconstruction loss: 294.1240, KL loss: 241.3361
# Total loss: 292.6925, Reconstruction loss: 290.2699, KL loss: 242.2669
# Total loss: 285.5336, Reconstruction loss: 283.1097, KL loss: 242.3901
# Total loss: 281.4958, Reconstruction loss: 279.0966, KL loss: 239.9104
# Total loss: 291.6665, Reconstruction loss: 289.1963, KL loss: 247.0194
# Total loss: 277.0654, Reconstruction loss: 274.5878, KL loss: 247.7598
# Total loss: 290.2337, Reconstruction loss: 287.8461, KL loss: 238.7661
# Total loss: 292.9205, Reconstruction loss: 290.4612, KL loss: 245.9240
# Total loss: 281.8412, Reconstruction loss: 279.4065, KL loss: 243.4653
# Total loss: 293.1211, Reconstruction loss: 290.6531, KL loss: 246.8061
# Total loss: 276.4745, Reconstruction loss: 273.9716, KL loss: 250.2969
# Total loss: 309.0649, Reconstruction loss: 306.5652, KL loss: 249.9734
# Total loss: 297.3352, Reconstruction loss: 294.8963, KL loss: 243.8901
# Total loss: 297.0069, Reconstruction loss: 294.5163, KL loss: 249.0656
# Total loss: 288.2831, Reconstruction loss: 285.8289, KL loss: 245.4229
# Total loss: 290.2970, Reconstruction loss: 287.7961, KL loss: 250.0916
# Total loss: 283.4696, Reconstruction loss: 281.0132, KL loss: 245.6479
# Total loss: 289.3724, Reconstruction loss: 286.9263, KL loss: 244.6102
# Total loss: 297.8852, Reconstruction loss: 295.3870, KL loss: 249.8205
# Total loss: 297.1974, Reconstruction loss: 294.6438, KL loss: 255.3626
# Total loss: 269.6158, Reconstruction loss: 267.1098, KL loss: 250.6038
# Total loss: 274.2012, Reconstruction loss: 271.6749, KL loss: 252.6330
# Total loss: 276.8002, Reconstruction loss: 274.2347, KL loss: 256.5421
# Total loss: 279.8496, Reconstruction loss: 277.3843, KL loss: 246.5309
# Total loss: 268.9478, Reconstruction loss: 266.3794, KL loss: 256.8465
# Total loss: 284.0363, Reconstruction loss: 281.4295, KL loss: 260.6775
# Total loss: 293.9795, Reconstruction loss: 291.4614, KL loss: 251.8104
# Total loss: 287.9307, Reconstruction loss: 285.3789, KL loss: 255.1721
# Total loss: 291.2807, Reconstruction loss: 288.7677, KL loss: 251.2966
# Epoch 7/10
# Total loss: 270.3075, Reconstruction loss: 267.7421, KL loss: 256.5388
# Total loss: 279.8121, Reconstruction loss: 277.2226, KL loss: 258.9494
# Total loss: 289.7691, Reconstruction loss: 287.2081, KL loss: 256.0934
# Total loss: 291.6928, Reconstruction loss: 289.1224, KL loss: 257.0447
# Total loss: 286.1852, Reconstruction loss: 283.6326, KL loss: 255.2639
# Total loss: 285.7922, Reconstruction loss: 283.2236, KL loss: 256.8622
# Total loss: 276.9250, Reconstruction loss: 274.3693, KL loss: 255.5653
# Total loss: 269.8181, Reconstruction loss: 267.2397, KL loss: 257.8395
# Total loss: 275.1492, Reconstruction loss: 272.5473, KL loss: 260.1863
# Total loss: 283.1253, Reconstruction loss: 280.5054, KL loss: 261.9891
# Total loss: 282.1016, Reconstruction loss: 279.4729, KL loss: 262.8649
# Total loss: 287.4985, Reconstruction loss: 284.8704, KL loss: 262.8101
# Total loss: 299.1475, Reconstruction loss: 296.5231, KL loss: 262.4400
# Total loss: 287.1979, Reconstruction loss: 284.5760, KL loss: 262.1982
# Total loss: 293.1916, Reconstruction loss: 290.5794, KL loss: 261.2237
# Total loss: 278.1859, Reconstruction loss: 275.5334, KL loss: 265.2435
# Total loss: 269.4580, Reconstruction loss: 266.7831, KL loss: 267.4930
# Total loss: 277.0826, Reconstruction loss: 274.4044, KL loss: 267.8184
# Total loss: 294.2253, Reconstruction loss: 291.5501, KL loss: 267.5261
# Total loss: 277.8492, Reconstruction loss: 275.2389, KL loss: 261.0351
# Total loss: 296.2725, Reconstruction loss: 293.6035, KL loss: 266.8993
# Total loss: 281.7608, Reconstruction loss: 279.0513, KL loss: 270.9548
# Total loss: 286.1259, Reconstruction loss: 283.5306, KL loss: 259.5294
# Total loss: 266.6264, Reconstruction loss: 263.9220, KL loss: 270.4442
# Total loss: 269.1011, Reconstruction loss: 266.3898, KL loss: 271.1320
# Total loss: 271.1555, Reconstruction loss: 268.4131, KL loss: 274.2417
# Total loss: 283.4889, Reconstruction loss: 280.7813, KL loss: 270.7608
# Total loss: 296.8180, Reconstruction loss: 294.0948, KL loss: 272.3205
# Total loss: 262.6329, Reconstruction loss: 259.8954, KL loss: 273.7505
# Total loss: 297.1236, Reconstruction loss: 294.3784, KL loss: 274.5274
# Total loss: 273.3085, Reconstruction loss: 270.5966, KL loss: 271.1926
# Total loss: 282.4501, Reconstruction loss: 279.6980, KL loss: 275.2097
# Total loss: 269.7607, Reconstruction loss: 267.0324, KL loss: 272.8323
# Total loss: 301.2362, Reconstruction loss: 298.5014, KL loss: 273.4771
# Total loss: 275.1986, Reconstruction loss: 272.4292, KL loss: 276.9427
# Total loss: 281.4141, Reconstruction loss: 278.6469, KL loss: 276.7165
# Total loss: 276.6232, Reconstruction loss: 273.8403, KL loss: 278.2855
# Total loss: 265.8155, Reconstruction loss: 263.0341, KL loss: 278.1446
# Total loss: 267.8730, Reconstruction loss: 265.1177, KL loss: 275.5258
# Total loss: 272.3571, Reconstruction loss: 269.5259, KL loss: 283.1182
# Total loss: 259.9024, Reconstruction loss: 257.0608, KL loss: 284.1623
# Total loss: 271.3836, Reconstruction loss: 268.6383, KL loss: 274.5270
# Total loss: 270.3609, Reconstruction loss: 267.5269, KL loss: 283.4013
# Total loss: 263.9200, Reconstruction loss: 261.1090, KL loss: 281.1048
# Total loss: 275.2533, Reconstruction loss: 272.4154, KL loss: 283.7847
# Total loss: 261.5381, Reconstruction loss: 258.6687, KL loss: 286.9341
# Total loss: 290.1365, Reconstruction loss: 287.2806, KL loss: 285.5900
# Total loss: 284.3952, Reconstruction loss: 281.5995, KL loss: 279.5710
# Total loss: 278.1487, Reconstruction loss: 275.2915, KL loss: 285.7195
# Total loss: 274.5931, Reconstruction loss: 271.7701, KL loss: 282.2955
# Total loss: 276.5818, Reconstruction loss: 273.6999, KL loss: 288.1887
# Total loss: 270.2343, Reconstruction loss: 267.4046, KL loss: 282.9723
# Total loss: 271.2277, Reconstruction loss: 268.4120, KL loss: 281.5665
# Total loss: 279.5561, Reconstruction loss: 276.6880, KL loss: 286.8090
# Total loss: 279.4123, Reconstruction loss: 276.4936, KL loss: 291.8720
# Total loss: 257.1166, Reconstruction loss: 254.2535, KL loss: 286.3054
# Total loss: 258.2026, Reconstruction loss: 255.3113, KL loss: 289.1324
# Total loss: 259.1232, Reconstruction loss: 256.1883, KL loss: 293.4887
# Total loss: 265.7386, Reconstruction loss: 262.9042, KL loss: 283.4342
# Total loss: 255.3843, Reconstruction loss: 252.4439, KL loss: 294.0372
# Total loss: 265.9576, Reconstruction loss: 262.9725, KL loss: 298.5021
# Total loss: 277.7664, Reconstruction loss: 274.8791, KL loss: 288.7370
# Total loss: 271.4490, Reconstruction loss: 268.5232, KL loss: 292.5803
# Total loss: 266.8167, Reconstruction loss: 263.9286, KL loss: 288.8030
# Epoch 8/10
# Total loss: 253.8861, Reconstruction loss: 250.9633, KL loss: 292.2766
# Total loss: 262.1334, Reconstruction loss: 259.1892, KL loss: 294.4202
# Total loss: 270.6313, Reconstruction loss: 267.7151, KL loss: 291.6195
# Total loss: 269.0582, Reconstruction loss: 266.1280, KL loss: 293.0162
# Total loss: 268.8032, Reconstruction loss: 265.8912, KL loss: 291.2053
# Total loss: 266.3077, Reconstruction loss: 263.3755, KL loss: 293.2177
# Total loss: 261.9819, Reconstruction loss: 259.0665, KL loss: 291.5408
# Total loss: 258.8692, Reconstruction loss: 255.9348, KL loss: 293.4430
# Total loss: 257.8640, Reconstruction loss: 254.9143, KL loss: 294.9709
# Total loss: 264.0637, Reconstruction loss: 261.1018, KL loss: 296.1885
# Total loss: 268.2997, Reconstruction loss: 265.3282, KL loss: 297.1575
# Total loss: 273.8623, Reconstruction loss: 270.8917, KL loss: 297.0621
# Total loss: 281.4461, Reconstruction loss: 278.4646, KL loss: 298.1542
# Total loss: 268.3561, Reconstruction loss: 265.3725, KL loss: 298.3609
# Total loss: 274.5103, Reconstruction loss: 271.5413, KL loss: 296.9003
# Total loss: 265.9663, Reconstruction loss: 262.9546, KL loss: 301.1707
# Total loss: 249.8793, Reconstruction loss: 246.8492, KL loss: 303.0099
# Total loss: 260.2458, Reconstruction loss: 257.2125, KL loss: 303.3327
# Total loss: 280.1478, Reconstruction loss: 277.1157, KL loss: 303.2177
# Total loss: 255.4048, Reconstruction loss: 252.4351, KL loss: 296.9708
# Total loss: 281.9036, Reconstruction loss: 278.8746, KL loss: 302.8928
# Total loss: 268.9704, Reconstruction loss: 265.8996, KL loss: 307.0856
# Total loss: 269.3868, Reconstruction loss: 266.4383, KL loss: 294.8503
# Total loss: 250.3186, Reconstruction loss: 247.2545, KL loss: 306.4077
# Total loss: 252.2134, Reconstruction loss: 249.1450, KL loss: 306.8448
# Total loss: 260.1656, Reconstruction loss: 257.0634, KL loss: 310.2233
# Total loss: 266.9849, Reconstruction loss: 263.9300, KL loss: 305.4924
# Total loss: 279.1263, Reconstruction loss: 276.0502, KL loss: 307.6030
# Total loss: 246.9596, Reconstruction loss: 243.8708, KL loss: 308.8759
# Total loss: 282.0010, Reconstruction loss: 278.8974, KL loss: 310.3563
# Total loss: 263.4937, Reconstruction loss: 260.4369, KL loss: 305.6830
# Total loss: 267.3085, Reconstruction loss: 264.2067, KL loss: 310.1753
# Total loss: 255.9418, Reconstruction loss: 252.8615, KL loss: 308.0353
# Total loss: 284.8249, Reconstruction loss: 281.7293, KL loss: 309.5601
# Total loss: 257.9756, Reconstruction loss: 254.8444, KL loss: 313.1199
# Total loss: 264.9093, Reconstruction loss: 261.7817, KL loss: 312.7582
# Total loss: 256.9749, Reconstruction loss: 253.8341, KL loss: 314.0882
# Total loss: 253.6279, Reconstruction loss: 250.4996, KL loss: 312.8337
# Total loss: 252.8139, Reconstruction loss: 249.7155, KL loss: 309.8361
# Total loss: 256.0580, Reconstruction loss: 252.8804, KL loss: 317.7552
# Total loss: 246.4738, Reconstruction loss: 243.2876, KL loss: 318.6198
# Total loss: 257.3102, Reconstruction loss: 254.2357, KL loss: 307.4587
# Total loss: 257.4105, Reconstruction loss: 254.2336, KL loss: 317.6873
# Total loss: 250.2388, Reconstruction loss: 247.0811, KL loss: 315.7734
# Total loss: 258.5921, Reconstruction loss: 255.4061, KL loss: 318.6049
# Total loss: 248.6764, Reconstruction loss: 245.4517, KL loss: 322.4674
# Total loss: 272.7678, Reconstruction loss: 269.5611, KL loss: 320.6736
# Total loss: 270.4260, Reconstruction loss: 267.2849, KL loss: 314.1066
# Total loss: 266.3611, Reconstruction loss: 263.1577, KL loss: 320.3392
# Total loss: 260.6029, Reconstruction loss: 257.4430, KL loss: 315.9882
# Total loss: 262.1461, Reconstruction loss: 258.9239, KL loss: 322.2219
# Total loss: 257.7509, Reconstruction loss: 254.5866, KL loss: 316.4344
# Total loss: 256.7085, Reconstruction loss: 253.5507, KL loss: 315.7862
# Total loss: 268.7596, Reconstruction loss: 265.5415, KL loss: 321.8076
# Total loss: 263.5366, Reconstruction loss: 260.2659, KL loss: 327.0701
# Total loss: 242.7937, Reconstruction loss: 239.5849, KL loss: 320.8802
# Total loss: 243.3848, Reconstruction loss: 240.1516, KL loss: 323.3114
# Total loss: 245.1431, Reconstruction loss: 241.8702, KL loss: 327.2860
# Total loss: 254.3723, Reconstruction loss: 251.2076, KL loss: 316.4646
# Total loss: 242.9492, Reconstruction loss: 239.6771, KL loss: 327.2123
# Total loss: 251.4705, Reconstruction loss: 248.1415, KL loss: 332.9010
# Total loss: 266.0683, Reconstruction loss: 262.8429, KL loss: 322.5410
# Total loss: 255.9557, Reconstruction loss: 252.6874, KL loss: 326.8297
# Total loss: 252.6446, Reconstruction loss: 249.4110, KL loss: 323.3585
# Epoch 9/10
# Total loss: 244.1496, Reconstruction loss: 240.8915, KL loss: 325.8114
# Total loss: 249.7198, Reconstruction loss: 246.4377, KL loss: 328.2117
# Total loss: 256.0146, Reconstruction loss: 252.7613, KL loss: 325.3239
# Total loss: 253.5652, Reconstruction loss: 250.2962, KL loss: 326.9025
# Total loss: 259.1050, Reconstruction loss: 255.8541, KL loss: 325.0961
# Total loss: 254.1165, Reconstruction loss: 250.8417, KL loss: 327.4763
# Total loss: 248.6052, Reconstruction loss: 245.3520, KL loss: 325.3225
# Total loss: 246.3429, Reconstruction loss: 243.0705, KL loss: 327.2463
# Total loss: 244.7569, Reconstruction loss: 241.4697, KL loss: 328.7205
# Total loss: 250.3025, Reconstruction loss: 247.0040, KL loss: 329.8501
# Total loss: 256.3598, Reconstruction loss: 253.0474, KL loss: 331.2406
# Total loss: 258.1862, Reconstruction loss: 254.8715, KL loss: 331.4764
# Total loss: 267.3219, Reconstruction loss: 263.9849, KL loss: 333.7020
# Total loss: 257.9495, Reconstruction loss: 254.6114, KL loss: 333.8136
# Total loss: 258.0397, Reconstruction loss: 254.7243, KL loss: 331.5335
# Total loss: 250.8298, Reconstruction loss: 247.4716, KL loss: 335.8187
# Total loss: 241.5390, Reconstruction loss: 238.1642, KL loss: 337.4859
# Total loss: 247.7288, Reconstruction loss: 244.3493, KL loss: 337.9519
# Total loss: 264.7113, Reconstruction loss: 261.3333, KL loss: 337.7980
# Total loss: 243.8697, Reconstruction loss: 240.5534, KL loss: 331.6294
# Total loss: 266.1566, Reconstruction loss: 262.7804, KL loss: 337.6160
# Total loss: 254.5950, Reconstruction loss: 251.1734, KL loss: 342.1591
# Total loss: 253.0019, Reconstruction loss: 249.7130, KL loss: 328.8907
# Total loss: 236.3194, Reconstruction loss: 232.9108, KL loss: 340.8533
# Total loss: 241.0500, Reconstruction loss: 237.6444, KL loss: 340.5616
# Total loss: 246.6391, Reconstruction loss: 243.1944, KL loss: 344.4698
# Total loss: 252.9179, Reconstruction loss: 249.5263, KL loss: 339.1555
# Total loss: 265.5743, Reconstruction loss: 262.1523, KL loss: 342.1967
# Total loss: 236.0805, Reconstruction loss: 232.6442, KL loss: 343.6257
# Total loss: 267.4588, Reconstruction loss: 263.9993, KL loss: 345.9500
# Total loss: 249.5276, Reconstruction loss: 246.1263, KL loss: 340.1364
# Total loss: 250.9864, Reconstruction loss: 247.5389, KL loss: 344.7479
# Total loss: 241.6388, Reconstruction loss: 238.2162, KL loss: 342.2569
# Total loss: 268.2359, Reconstruction loss: 264.7953, KL loss: 344.0551
# Total loss: 245.4084, Reconstruction loss: 241.9325, KL loss: 347.5878
# Total loss: 250.7420, Reconstruction loss: 247.2690, KL loss: 347.2991
# Total loss: 244.7103, Reconstruction loss: 241.2200, KL loss: 349.0231
# Total loss: 237.5092, Reconstruction loss: 234.0360, KL loss: 347.3149
# Total loss: 238.9871, Reconstruction loss: 235.5472, KL loss: 343.9931
# Total loss: 240.9488, Reconstruction loss: 237.4257, KL loss: 352.3130
# Total loss: 236.1012, Reconstruction loss: 232.5672, KL loss: 353.3965
# Total loss: 244.1023, Reconstruction loss: 240.6904, KL loss: 341.1900
# Total loss: 245.1922, Reconstruction loss: 241.6639, KL loss: 352.8300
# Total loss: 237.6796, Reconstruction loss: 234.1716, KL loss: 350.7980
# Total loss: 244.6344, Reconstruction loss: 241.1003, KL loss: 353.4118
# Total loss: 236.6050, Reconstruction loss: 233.0275, KL loss: 357.7565
# Total loss: 256.0916, Reconstruction loss: 252.5341, KL loss: 355.7471
# Total loss: 259.4021, Reconstruction loss: 255.9095, KL loss: 349.2557
# Total loss: 249.7125, Reconstruction loss: 246.1514, KL loss: 356.1132
# Total loss: 242.5669, Reconstruction loss: 239.0536, KL loss: 351.3297
# Total loss: 251.1158, Reconstruction loss: 247.5303, KL loss: 358.5469
# Total loss: 242.4926, Reconstruction loss: 238.9720, KL loss: 352.0593
# Total loss: 242.8975, Reconstruction loss: 239.3806, KL loss: 351.6870
# Total loss: 257.3668, Reconstruction loss: 253.7846, KL loss: 358.2194
# Total loss: 248.8096, Reconstruction loss: 245.1775, KL loss: 363.2013
# Total loss: 232.2542, Reconstruction loss: 228.6924, KL loss: 356.1860
# Total loss: 232.8241, Reconstruction loss: 229.2381, KL loss: 358.6041
# Total loss: 233.8585, Reconstruction loss: 230.2299, KL loss: 362.8584
# Total loss: 240.5175, Reconstruction loss: 237.0044, KL loss: 351.3076
# Total loss: 234.2905, Reconstruction loss: 230.6676, KL loss: 362.2909
# Total loss: 238.4952, Reconstruction loss: 234.8049, KL loss: 369.0265
# Total loss: 255.9406, Reconstruction loss: 252.3576, KL loss: 358.3023
# Total loss: 243.0219, Reconstruction loss: 239.3855, KL loss: 363.6375
# Total loss: 235.0404, Reconstruction loss: 231.4354, KL loss: 360.4979
# Epoch 10/10
# Total loss: 231.0613, Reconstruction loss: 227.4441, KL loss: 361.7246
# Total loss: 237.5377, Reconstruction loss: 233.8976, KL loss: 364.0154
# Total loss: 240.8956, Reconstruction loss: 237.2842, KL loss: 361.1306
# Total loss: 241.3395, Reconstruction loss: 237.7137, KL loss: 362.5795
# Total loss: 245.3317, Reconstruction loss: 241.7271, KL loss: 360.4619
# Total loss: 241.1930, Reconstruction loss: 237.5631, KL loss: 362.9818
# Total loss: 236.1276, Reconstruction loss: 232.5237, KL loss: 360.3931
# Total loss: 234.2077, Reconstruction loss: 230.5837, KL loss: 362.4034
# Total loss: 233.4183, Reconstruction loss: 229.7795, KL loss: 363.8854
# Total loss: 237.1084, Reconstruction loss: 233.4596, KL loss: 364.8782
# Total loss: 243.0403, Reconstruction loss: 239.3724, KL loss: 366.7923
# Total loss: 248.0164, Reconstruction loss: 244.3479, KL loss: 366.8521
# Total loss: 250.8580, Reconstruction loss: 247.1582, KL loss: 369.9818
# Total loss: 243.7338, Reconstruction loss: 240.0351, KL loss: 369.8698
# Total loss: 245.1282, Reconstruction loss: 241.4559, KL loss: 367.2309
# Total loss: 238.7542, Reconstruction loss: 235.0390, KL loss: 371.5250
# Total loss: 228.2807, Reconstruction loss: 224.5502, KL loss: 373.0554
# Total loss: 236.4866, Reconstruction loss: 232.7497, KL loss: 373.6957
# Total loss: 249.9775, Reconstruction loss: 246.2399, KL loss: 373.7581
# Total loss: 229.6806, Reconstruction loss: 226.0031, KL loss: 367.7495
# Total loss: 250.2998, Reconstruction loss: 246.5609, KL loss: 373.8922
# Total loss: 241.9352, Reconstruction loss: 238.1494, KL loss: 378.5801
# Total loss: 240.0433, Reconstruction loss: 236.4014, KL loss: 364.1925
# Total loss: 223.9436, Reconstruction loss: 220.1741, KL loss: 376.9499
# Total loss: 227.2322, Reconstruction loss: 223.4696, KL loss: 376.2608
# Total loss: 236.4646, Reconstruction loss: 232.6574, KL loss: 380.7228
# Total loss: 240.1706, Reconstruction loss: 236.4239, KL loss: 374.6676
# Total loss: 249.3050, Reconstruction loss: 245.5250, KL loss: 378.0041
# Total loss: 224.7816, Reconstruction loss: 220.9898, KL loss: 379.1740
# Total loss: 252.9009, Reconstruction loss: 249.0774, KL loss: 382.3581
# Total loss: 235.5599, Reconstruction loss: 231.8037, KL loss: 375.6156
# Total loss: 238.6532, Reconstruction loss: 234.8516, KL loss: 380.1667
# Total loss: 228.2062, Reconstruction loss: 224.4318, KL loss: 377.4390
# Total loss: 251.9557, Reconstruction loss: 248.1641, KL loss: 379.1626
# Total loss: 233.9117, Reconstruction loss: 230.0873, KL loss: 382.4391
# Total loss: 239.5518, Reconstruction loss: 235.7295, KL loss: 382.2281
# Total loss: 233.9189, Reconstruction loss: 230.0775, KL loss: 384.1473
# Total loss: 224.6736, Reconstruction loss: 220.8533, KL loss: 382.0362
# Total loss: 224.2300, Reconstruction loss: 220.4451, KL loss: 378.4933
# Total loss: 225.7953, Reconstruction loss: 221.9216, KL loss: 387.3713
# Total loss: 222.2265, Reconstruction loss: 218.3393, KL loss: 388.7144
# Total loss: 231.0375, Reconstruction loss: 227.2826, KL loss: 375.4926
# Total loss: 232.2134, Reconstruction loss: 228.3331, KL loss: 388.0282
# Total loss: 225.5360, Reconstruction loss: 221.6769, KL loss: 385.9017
# Total loss: 233.9186, Reconstruction loss: 230.0343, KL loss: 388.4229
# Total loss: 221.9720, Reconstruction loss: 218.0364, KL loss: 393.5594
# Total loss: 243.1933, Reconstruction loss: 239.2833, KL loss: 391.0031
# Total loss: 248.0110, Reconstruction loss: 244.1704, KL loss: 384.0549
# Total loss: 237.2164, Reconstruction loss: 233.3042, KL loss: 391.2188
# Total loss: 230.7607, Reconstruction loss: 226.9044, KL loss: 385.6324
# Total loss: 236.0511, Reconstruction loss: 232.1160, KL loss: 393.5128
# Total loss: 232.8160, Reconstruction loss: 228.9511, KL loss: 386.4885
# Total loss: 231.3057, Reconstruction loss: 227.4386, KL loss: 386.7091
# Total loss: 242.1750, Reconstruction loss: 238.2384, KL loss: 393.6571
# Total loss: 237.2852, Reconstruction loss: 233.3032, KL loss: 398.1995
# Total loss: 220.5904, Reconstruction loss: 216.6875, KL loss: 390.2902
# Total loss: 218.6380, Reconstruction loss: 214.7100, KL loss: 392.8028
# Total loss: 222.1086, Reconstruction loss: 218.1323, KL loss: 397.6354
# Total loss: 229.0003, Reconstruction loss: 225.1426, KL loss: 385.7722
# Total loss: 221.9646, Reconstruction loss: 217.9937, KL loss: 397.0862
# Total loss: 224.8942, Reconstruction loss: 220.8486, KL loss: 404.5666
# Total loss: 242.7221, Reconstruction loss: 238.7936, KL loss: 392.8426
# Total loss: 230.4420, Reconstruction loss: 226.4548, KL loss: 398.7231
# Total loss: 218.1749, Reconstruction loss: 214.2128, KL loss: 396.2118

# %%
# Evaluate the trained model on the test dataset
test_loss = []
for batch_images, batch_color_ids, batch_binary_attributes in test_dataset:
    reconstructed_images, z_mean, z_log_var = cvae([batch_images, batch_color_ids, batch_binary_attributes])
    rec_loss = reconstruction_loss(batch_images, reconstructed_images)
    rec_loss = tf.reduce_mean(rec_loss)
    kl_loss = -0.5 * tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1)
    kl_loss = tf.reduce_mean(kl_loss)
    total_loss = rec_loss + kl_loss
    test_loss.append(total_loss)

test_loss = tf.reduce_mean(test_loss)
print(f"Test loss: {test_loss:.4f}")
# Out:
# Test loss: 396.6946

# %%
import matplotlib.pyplot as plt

def show(image_batch):
    plt.figure(figsize=(10,10))
    for n in range(4):
        ax = plt.subplot(1,4,n+1)
        plt.imshow(image_batch[n])
        plt.axis('off')
    plt.show()

for batch_images, batch_color_ids, batch_binary_attributes in test_dataset.take(2):
    reconstructed_images, _, _ = cvae([batch_images, batch_color_ids, batch_binary_attributes])
    show(batch_images)
    show(reconstructed_images)

# %%
def regenerate_image(image, new_color_id, new_binary_attributes):
    image = tf.expand_dims(image, axis=0)
    new_color_id = tf.expand_dims(new_color_id, axis=0)
    new_binary_attributes = tf.expand_dims(new_binary_attributes, axis=0)

    # Get color embeddings
    color_embeds = cvae.color_embedding(new_color_id)

    # Concatenate color embeddings with binary attributes
    attribute_vector = layers.Concatenate(axis=-1)([color_embeds, new_binary_attributes])

    # Encode input image and attributes
    z_mean, z_log_var = cvae.encoder([image, attribute_vector])

    # Sample from the latent space
    batch_size = tf.shape(image)[0]
    epsilon = tf.random.normal(shape=(batch_size, latent_dimension))
    z = z_mean + tf.exp(0.5 * z_log_var) * epsilon

    # Concatenate latent vector with the attribute vector
    z_cond = layers.Concatenate(axis=-1)([z, attribute_vector])

    # Decode the conditioned latent vector
    regenerated_image = cvae.decoder(z_cond)

    return regenerated_image[0]

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

file = "data/img/id_00006158.jpg"
# Load the input image and preprocess it
input_image = cv2.imread(file)
input_image = cv2.resize(input_image, (64, 64))
input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
input_image = input_image / 255.0

# Define new color ID and binary attributes
new_color_id = 299  # Any integer value between 0 and 758 (num_colors - 1)
print(list(color_vocabulary.keys())[list(color_vocabulary.values()).index(new_color_id)])
#new_binary_attributes = np.random.randint(0, 2, size=(num_binary_attributes,)).astype(np.float32)
binary_attributes = item_attr_data[item_attr_data['img_idx']==file[9:-4]]
binary_attributes = binary_attributes.drop(columns=['index','img_idx','clothes_color'])

new_binary_attributes = binary_attributes.to_numpy(dtype=np.float32).flatten()
new_binary_attributes = (new_binary_attributes + 1) / 2


# Generate the new image
regenerated_image = regenerate_image(input_image, new_color_id, new_binary_attributes)

# Plot the input and regenerated images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.imshow(input_image)
ax1.set_title("Input Image")
ax1.axis("off")

ax2.imshow(regenerated_image)
ax2.set_title("Regenerated Image")
ax2.axis("off")

plt.show()
# Out:
# Green-blue
